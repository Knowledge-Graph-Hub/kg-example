# %% [markdown]
# # KG-Hub: Machine Learning on Knowledge Graphs

# %% [markdown]
# This walkthrough provides a basic introduction to preparing KG-Hub projects for graph-based machine learning and analysis. It assumes you have already set up a KG-Hub project and have produced a merged graph. The graph should be in the `/data/merged/` directory, named `merged-kg.tar.gz`, and be in KGX TSV format.
#
# If the merged graph is somewhere else, change the value for `merged_graph_path` below. Otherwise, just run that code block.

# %%
merged_graph_path = "../data/merged/merged-kg.tar.gz"

# %% [markdown]
# If you don't already have a graph and just want to dive in, run this next block. It will download a copy of the MONDO disease ontology graph from KG-OBO. This is not the most exciting input, but it's comparatively small and will still work in the following examples.

# %%
# !wget https://kg-hub.berkeleybop.io/kg-obo/mondo/2022-02-04/mondo_kgx_tsv.tar.gz
# Out:
# --2022-06-28 15:49:31--  https://kg-hub.berkeleybop.io/kg-obo/mondo/2022-02-04/mondo_kgx_tsv.tar.gz
# Resolving kg-hub.berkeleybop.io (kg-hub.berkeleybop.io)... 52.85.151.29, 52.85.151.90, 52.85.151.118, ...
# Connecting to kg-hub.berkeleybop.io (kg-hub.berkeleybop.io)|52.85.151.29|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8420745 (8.0M) [plain/text]
# Saving to: ‘mondo_kgx_tsv.tar.gz’
#
# mondo_kgx_tsv.tar.g 100%[===================>]   8.03M  17.7MB/s    in 0.5s
#
# 2022-06-28 15:49:32 (17.7 MB/s) - ‘mondo_kgx_tsv.tar.gz’ saved [8420745/8420745]

# %%
merged_graph_path = "./mondo_kgx_tsv.tar.gz"

# %% [markdown]
# ## Loading and processing graphs with GraPE

# %% [markdown]
# The [Graph Processing and Embedding (GraPE) package](https://github.com/AnacletoLAB/grape) is a comprehensive toolbox for loading, processing, describing, and otherwise learning from graphs. It has two primary components: Ensmallen, which handles graph processing, and Embiggen, which produces embeddings. Working with large, complex graphs can be very computationally intensive, so the GraPE tools use a variety of strategies to optimize efficiency. They also work very well with KG-Hub graphs!
#
# [The full documentation for GraPE is here.](https://anacletolab.github.io/grape/index.html) You'll see that it offers a sizable collection of functions, so feel free to explore. There are also [tutorial notebooks](https://github.com/AnacletoLAB/grape/tree/main/tutorials) to peruse. For now, let's get GraPE ready, load a graph, and learn about its features.

# %% [markdown]
# First, install GraPE and a variety of other dependencies with `pip`:

# %%
# %pip install grape -U
# Out:
# Requirement already satisfied: grape in /home/harry/kg-env/lib/python3.8/site-packages (0.1.8)
# Requirement already satisfied: embiggen>=0.11.12 in /home/harry/kg-env/lib/python3.8/site-packages (from grape) (0.11.12)
# Requirement already satisfied: ensmallen>=0.8.5 in /home/harry/kg-env/lib/python3.8/site-packages (from grape) (0.8.5)
# Requirement already satisfied: keras-mixed-sequence>=1.0.28 in /home/harry/kg-env/lib/python3.8/site-packages (from embiggen>=0.11.12->grape) (1.0.28)
# Requirement already satisfied: validate-version-code in /home/harry/kg-env/lib/python3.8/site-packages (from embiggen>=0.11.12->grape) (1.0.4)
# Requirement already satisfied: sanitize-ml-labels>=1.0.38 in /home/harry/kg-env/lib/python3.8/site-packages (from embiggen>=0.11.12->grape) (1.0.42)
# Requirement already satisfied: cache-decorator>=2.1.8 in /home/harry/kg-env/lib/python3.8/site-packages (from embiggen>=0.11.12->grape) (2.1.8)
# Requirement already satisfied: pandas in /home/harry/kg-env/lib/python3.8/site-packages (from embiggen>=0.11.12->grape) (1.4.2)
# Requirement already satisfied: numpy in /home/harry/kg-env/lib/python3.8/site-packages (from embiggen>=0.11.12->grape) (1.22.3)
# Requirement already satisfied: scikit-learn in /home/harry/kg-env/lib/python3.8/site-packages (from embiggen>=0.11.12->grape) (1.0.2)
# Requirement already satisfied: extra-keras-metrics>=2.0.7 in /home/harry/kg-env/lib/python3.8/site-packages (from embiggen>=0.11.12->grape) (2.0.7)
# Requirement already satisfied: tqdm in /home/harry/kg-env/lib/python3.8/site-packages (from embiggen>=0.11.12->grape) (4.63.0)
# Requirement already satisfied: matplotlib>=3.5.2 in /home/harry/kg-env/lib/python3.8/site-packages (from embiggen>=0.11.12->grape) (3.5.2)
# Requirement already satisfied: ddd-subplots>=1.0.19 in /home/harry/kg-env/lib/python3.8/site-packages (from embiggen>=0.11.12->grape) (1.0.19)
# Requirement already satisfied: packaging in /home/harry/kg-env/lib/python3.8/site-packages (from embiggen>=0.11.12->grape) (21.3)
# Requirement already satisfied: py-cpuinfo in /home/harry/kg-env/lib/python3.8/site-packages/py_cpuinfo-8.0.0-py3.8.egg (from ensmallen>=0.8.5->grape) (8.0.0)
# Requirement already satisfied: toml~=0.10.0 in /home/harry/kg-env/lib/python3.8/site-packages (from ensmallen>=0.8.5->grape) (0.10.2)
# Requirement already satisfied: compress_json>=1.0.6 in /home/harry/kg-env/lib/python3.8/site-packages (from ensmallen>=0.8.5->grape) (1.0.7)
# Requirement already satisfied: transformers in /home/harry/kg-env/lib/python3.8/site-packages/transformers-4.12.5-py3.8.egg (from ensmallen>=0.8.5->grape) (4.12.5)
# Requirement already satisfied: userinput>=1.0.17 in /home/harry/kg-env/lib/python3.8/site-packages (from ensmallen>=0.8.5->grape) (1.0.17)
# Requirement already satisfied: downloaders>=1.0.15 in /home/harry/kg-env/lib/python3.8/site-packages (from ensmallen>=0.8.5->grape) (1.0.15)
# Requirement already satisfied: environments_utils>=1.0.4 in /home/harry/kg-env/lib/python3.8/site-packages (from ensmallen>=0.8.5->grape) (1.0.4)
# Requirement already satisfied: dict-hash>=1.1.25 in /home/harry/kg-env/lib/python3.8/site-packages (from cache-decorator>=2.1.8->embiggen>=0.11.12->grape) (1.1.26)
# Requirement already satisfied: compress-pickle>=2.0.1 in /home/harry/kg-env/lib/python3.8/site-packages/compress_pickle-2.1.0-py3.8.egg (from cache-decorator>=2.1.8->embiggen>=0.11.12->grape) (2.1.0)
# Requirement already satisfied: humanize>=3.4.1 in /home/harry/kg-env/lib/python3.8/site-packages/humanize-3.12.0-py3.8.egg (from cache-decorator>=2.1.8->embiggen>=0.11.12->grape) (3.12.0)
# Requirement already satisfied: deflate-dict in /home/harry/kg-env/lib/python3.8/site-packages/deflate_dict-1.0.9-py3.8.egg (from cache-decorator>=2.1.8->embiggen>=0.11.12->grape) (1.0.9)
# Requirement already satisfied: opencv-python in /home/harry/kg-env/lib/python3.8/site-packages/opencv_python-4.5.4.60-py3.8-linux-x86_64.egg (from ddd-subplots>=1.0.19->embiggen>=0.11.12->grape) (4.5.4.60)
# Requirement already satisfied: sklearn in /home/harry/kg-env/lib/python3.8/site-packages/sklearn-0.0-py3.8.egg (from ddd-subplots>=1.0.19->embiggen>=0.11.12->grape) (0.0)
# Requirement already satisfied: pygifsicle in /home/harry/kg-env/lib/python3.8/site-packages/pygifsicle-1.0.5-py3.8.egg (from ddd-subplots>=1.0.19->embiggen>=0.11.12->grape) (1.0.5)
# Requirement already satisfied: imageio in /home/harry/kg-env/lib/python3.8/site-packages/imageio-2.10.1-py3.8.egg (from ddd-subplots>=1.0.19->embiggen>=0.11.12->grape) (2.10.1)
# Requirement already satisfied: decorator in /home/harry/kg-env/lib/python3.8/site-packages (from extra-keras-metrics>=2.0.7->embiggen>=0.11.12->grape) (5.1.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/harry/kg-env/lib/python3.8/site-packages (from matplotlib>=3.5.2->embiggen>=0.11.12->grape) (3.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /home/harry/kg-env/lib/python3.8/site-packages/fonttools-4.27.1-py3.8.egg (from matplotlib>=3.5.2->embiggen>=0.11.12->grape) (4.27.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/harry/kg-env/lib/python3.8/site-packages/kiwisolver-1.3.2-py3.8-linux-x86_64.egg (from matplotlib>=3.5.2->embiggen>=0.11.12->grape) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/harry/kg-env/lib/python3.8/site-packages (from matplotlib>=3.5.2->embiggen>=0.11.12->grape) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/harry/kg-env/lib/python3.8/site-packages/Pillow-8.4.0-py3.8-linux-x86_64.egg (from matplotlib>=3.5.2->embiggen>=0.11.12->grape) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /home/harry/kg-env/lib/python3.8/site-packages/cycler-0.10.0-py3.8.egg (from matplotlib>=3.5.2->embiggen>=0.11.12->grape) (0.10.0)
# Requirement already satisfied: validate-email in /home/harry/kg-env/lib/python3.8/site-packages/validate_email-1.3-py3.8.egg (from userinput>=1.0.17->ensmallen>=0.8.5->grape) (1.3)
# Requirement already satisfied: validators in /home/harry/kg-env/lib/python3.8/site-packages (from userinput>=1.0.17->ensmallen>=0.8.5->grape) (0.18.2)
# Requirement already satisfied: IPy in /home/harry/kg-env/lib/python3.8/site-packages/IPy-1.1-py3.8.egg (from userinput>=1.0.17->ensmallen>=0.8.5->grape) (1.1)
# Requirement already satisfied: jaro-winkler in /home/harry/kg-env/lib/python3.8/site-packages (from userinput>=1.0.17->ensmallen>=0.8.5->grape) (2.0.0)
# Requirement already satisfied: ipython in /home/harry/kg-env/lib/python3.8/site-packages (from userinput>=1.0.17->ensmallen>=0.8.5->grape) (8.1.1)
# Requirement already satisfied: pytz>=2020.1 in /home/harry/kg-env/lib/python3.8/site-packages (from pandas->embiggen>=0.11.12->grape) (2021.3)
# Requirement already satisfied: scipy>=1.1.0 in /home/harry/kg-env/lib/python3.8/site-packages (from scikit-learn->embiggen>=0.11.12->grape) (1.8.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/harry/kg-env/lib/python3.8/site-packages/threadpoolctl-3.0.0-py3.8.egg (from scikit-learn->embiggen>=0.11.12->grape) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /home/harry/kg-env/lib/python3.8/site-packages (from scikit-learn->embiggen>=0.11.12->grape) (1.0.1)
# Requirement already satisfied: filelock in /home/harry/kg-env/lib/python3.8/site-packages (from transformers->ensmallen>=0.8.5->grape) (3.6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /home/harry/kg-env/lib/python3.8/site-packages/huggingface_hub-0.2.1-py3.8.egg (from transformers->ensmallen>=0.8.5->grape) (0.2.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/harry/kg-env/lib/python3.8/site-packages (from transformers->ensmallen>=0.8.5->grape) (5.4.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/harry/kg-env/lib/python3.8/site-packages (from transformers->ensmallen>=0.8.5->grape) (2021.8.28)
# Requirement already satisfied: requests in /home/harry/kg-env/lib/python3.8/site-packages (from transformers->ensmallen>=0.8.5->grape) (2.27.1)
# Requirement already satisfied: sacremoses in /home/harry/kg-env/lib/python3.8/site-packages/sacremoses-0.0.46-py3.8.egg (from transformers->ensmallen>=0.8.5->grape) (0.0.46)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /home/harry/kg-env/lib/python3.8/site-packages/tokenizers-0.10.3-py3.8-linux-x86_64.egg (from transformers->ensmallen>=0.8.5->grape) (0.10.3)
# Requirement already satisfied: six in /home/harry/kg-env/lib/python3.8/site-packages (from cycler>=0.10->matplotlib>=3.5.2->embiggen>=0.11.12->grape) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/harry/kg-env/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers->ensmallen>=0.8.5->grape) (4.1.1)
# Requirement already satisfied: setuptools in /home/harry/kg-env/lib/python3.8/site-packages (from humanize>=3.4.1->cache-decorator>=2.1.8->embiggen>=0.11.12->grape) (60.9.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/harry/kg-env/lib/python3.8/site-packages (from ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape) (3.0.28)
# Requirement already satisfied: backcall in /home/harry/kg-env/lib/python3.8/site-packages/backcall-0.2.0-py3.8.egg (from ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in /home/harry/kg-env/lib/python3.8/site-packages (from ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape) (2.11.2)
# Requirement already satisfied: matplotlib-inline in /home/harry/kg-env/lib/python3.8/site-packages/matplotlib_inline-0.1.3-py3.8.egg (from ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape) (0.1.3)
# Requirement already satisfied: jedi>=0.16 in /home/harry/kg-env/lib/python3.8/site-packages (from ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape) (0.18.1)
# Requirement already satisfied: pickleshare in /home/harry/kg-env/lib/python3.8/site-packages/pickleshare-0.7.5-py3.8.egg (from ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /home/harry/kg-env/lib/python3.8/site-packages/pexpect-4.8.0-py3.8.egg (from ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape) (4.8.0)
# Requirement already satisfied: stack-data in /home/harry/kg-env/lib/python3.8/site-packages (from ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /home/harry/kg-env/lib/python3.8/site-packages/traitlets-5.1.1-py3.8.egg (from ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape) (5.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/harry/kg-env/lib/python3.8/site-packages (from requests->transformers->ensmallen>=0.8.5->grape) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/harry/kg-env/lib/python3.8/site-packages (from requests->transformers->ensmallen>=0.8.5->grape) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/harry/kg-env/lib/python3.8/site-packages (from requests->transformers->ensmallen>=0.8.5->grape) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/harry/kg-env/lib/python3.8/site-packages (from requests->transformers->ensmallen>=0.8.5->grape) (2.0.12)
# Requirement already satisfied: click in /home/harry/kg-env/lib/python3.8/site-packages (from sacremoses->transformers->ensmallen>=0.8.5->grape) (7.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/harry/kg-env/lib/python3.8/site-packages (from jedi>=0.16->ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/harry/kg-env/lib/python3.8/site-packages/ptyprocess-0.7.0-py3.8.egg (from pexpect>4.3->ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape) (0.7.0)
# Requirement already satisfied: wcwidth in /home/harry/kg-env/lib/python3.8/site-packages/wcwidth-0.2.5-py3.8.egg (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape) (0.2.5)
# Requirement already satisfied: pure-eval in /home/harry/kg-env/lib/python3.8/site-packages (from stack-data->ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape) (0.2.2)
# Requirement already satisfied: executing in /home/harry/kg-env/lib/python3.8/site-packages (from stack-data->ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape) (0.8.3)
# Requirement already satisfied: asttokens in /home/harry/kg-env/lib/python3.8/site-packages (from stack-data->ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape) (2.0.5)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/home/harry/kg-env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Every graph in Ensmallen is loaded as a `Graph` object, so we import that class (and `random`, because we'll use it later):

# %%
from grape import Graph
import random

# %% [markdown]
# Decompress the graph, as Ensmallen will expect separate node and edge files. If your node and edge filenames differ from the values for `merged_node_filename` and `merged_edge_filename` below, please change them.

# %%
# !tar xvzf $merged_graph_path

# %%
merged_node_filename = "merged-kg_nodes.tsv"
merged_edge_filename = "merged-kg_edges.tsv"

# %% [markdown]
# Load the graph with Ensmallen's `from_csv` (don't worry, we will tell it that these are tsv files, not csv):

# %%
a_big_graph = Graph.from_csv(
    node_path=merged_node_filename,
    edge_path=merged_edge_filename,
    node_list_separator="\t",
    edge_list_separator="\t",
    node_list_header=True,  # Always true for KG-Hub KGs
    edge_list_header=True,  # Always true for KG-Hub KGs
    nodes_column='id',  # Always true for KG-Hub KGs
    node_list_node_types_column='category',  # Always true for KG-Hub KGs
    sources_column='subject',  # Always true for KG-Hub KGs
    destinations_column='object',  # Always true for KG-Hub KGs
    directed=False,
    name="A_Big_Graph",
    verbose=True
)

a_big_graph
# Out:
# <div class="graph-report"><style>.graph-report li {margin: 0.5em 0 0.5em 0;}.graph-report .paragraph {text-align: justify;word-break: break-all;}.graph-report .small-columns {column-count: 4;column-gap: 2em;}.graph-report .medium-columns {column-count: 3;column-gap: 2em;}.graph-report .large-columns {column-count: 2;column-gap: 2em;}.graph-report .single-column {}@media only screen and (max-width: 600px) {.graph-report .small-columns {column-count: 1;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 600px) and (max-width: 800px) {.graph-report .small-columns {column-count: 2;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 800px) and (max-width: 1024px) {.graph-report .small-columns {column-count: 3;}.graph-report .medium-columns {column-count: 2;}.graph-report .large-columns {column-count: 1;}}</style><h2>A_Big_Graph</h2><p class="paragraph">The undirected graph A_Big_Graph has 232.98K heterogeneous nodes and 695.51K edges. The graph contains 450 connected components (of which 436 are disconnected nodes), with the largest one containing 232.50K nodes and the smallest one containing a single node. The RAM requirements for the nodes and edges data structures are 27.64MB and 3.04MB respectively.</p><h3 style="margin: 1em 0 0 0;">Degree centrality</h3><p class="paragraph">The minimum node degree is 0, the maximum node degree is 96.90K, the mode degree is 2, the mean degree is 5.97 and the node degree median is 2.</p><p class="paragraph">The nodes with the highest degree centrality are <a href='http://purl.obolibrary.org/obo/chebi#2_STAR' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:chebi#2_STAR'>OBO:chebi#2_STAR</a> (degree 96.90K and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='http://purl.obolibrary.org/obo/chebi#3_STAR' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:chebi#3_STAR'>OBO:chebi#3_STAR</a> (degree 59.86K and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='http://purl.obolibrary.org/obo/IAO_0000428' target='_blank' title='Go to Information Artifact Ontology to get more informations about IAO:0000428'>IAO:0000428</a> (degree 19.84K and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='http://purl.obolibrary.org/obo/IAO_0000227' target='_blank' title='Go to Information Artifact Ontology to get more informations about IAO:0000227'>IAO:0000227</a> (degree 18.51K and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:24995' target='_blank' title='Go to CHEBI to get more informations about CHEBI:24995'>CHEBI:24995</a> (degree 7.34K and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p><h3 style="margin: 1em 0 0 0;">Node types</h3><p class="paragraph">The graph has 3 node types, which are <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a> (209.22K nodes, 89.80%), <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity ...
# <li><p class="paragraph"><a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:60042' target='_blank' title='Go to CHEBI to get more informations about CHEBI:60042'>CHEBI:60042</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:53148' target='_blank' title='Go to CHEBI to get more informations about CHEBI:53148'>CHEBI:53148</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:77533' target='_blank' title='Go to CHEBI to get more informations about CHEBI:77533'>CHEBI:77533</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:137364' target='_blank' title='Go to CHEBI to get more informations about CHEBI:137364'>CHEBI:137364</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:138289' target='_blank' title='Go to CHEBI to get more informations about CHEBI:138289'>CHEBI:138289</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:75924' target='_blank' title='Go to CHEBI to get more informations about CHEBI:75924'>CHEBI:75924</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='http://www.geneontology.org/formats/oboInOwl#inSubset' target='_blank' title='Go to Gene Ontology OBO in OWL to get more informations about OIO:inSubset'>OIO:inSubset</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:75983' target='_blank' title='Go to CHEBI to get more informations about CHEBI:75983'>CHEBI:75983</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:63603' target='_blank' title='Go to CHEBI to get more informations about CHEBI:63603'>CHEBI:63603</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='http://www.w3.org/2000/01/rdf-schema#comment' target='_blank' title='Go to RDFS to get more informations about rdfs:comment'>rdfs:comment</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='http://www.geneontology.org/formats/oboInOwl#shorthand' target='_blank' title='Go to Gene Ontology OBO in OWL to get more informations about OIO:shorthand'>OIO:shorthand</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/RO_0001025' target='_blank' title='Go to Relation Ontology to get more informations about RO:0001025'>RO:0001025</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/FOODON_03401024' target='_blank' title='Go to FOODON to get more informations about FOODON:03401024'>FOODON:03401024</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/FOODON_03310770' target='_blank' title='Go to FOODON to get more informations about FOODON:03310770'>FOODON:03310770</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li></ul><p class="paragraph">And other 421 singleton nodes.</p><h4 style="margin: 1em 0 0 0;">Node tuples</h4><p class="paragraph">A node tuple is a connected component composed of two nodes. We have detected 4 node tuples in the graph, involving a total of 8 nodes and 4 edges. The detected node tuples are:</p><ul class="medium-columns"><li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/HANCESTRO_0032' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:HANCESTRO_0032'>OBO:HANCESTRO_0032</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/hancestro_0032' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:hancestro_0032'>OBO:hancestro_0032</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/chebi#is_conjugate_acid_of' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:chebi#is_conjugate_acid_of'>OBO:chebi#is_conjugate_acid_of</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/chebi#is_conjugate_base_of' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:chebi#is_conjugate_base_of'>OBO:chebi#is_conjugate_base_of</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://www.langual.org/langual_thesaurus.asp?termid=C0165' target='_blank' title='Go to website to get more informations about http:&#x2f;&#x2f;www.langual.org&#x2f;langual_thesaurus.asp?termid=C0165'>http:&#x2f;&#x2f;www.langual.org&#x2f;langual_thesaurus.asp?termid=C0165</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/FOODON_03420165' target='_blank' title='Go to FOODON to get more informations about FOODON:03420165'>FOODON:03420165</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/HANCESTRO_0033' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:HANCESTRO_0033'>OBO:HANCESTRO_0033</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/hancestro_0033' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:hancestro_0033'>OBO:hancestro_0033</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li></ul><h4 style="margin: 1em 0 0 0;">Isomorphic node groups</h4><p class="paragraph">Isomorphic groups are nodes with exactly the same neighbours and node types (if present in the graph). Nodes in such groups are topologically indistinguishable, that is swapping their ID would not change the graph topology. We have detected 755 isomorphic node groups in the graph, involving a total of 1.93K nodes (0.83%) and 13.10K edges (0.94%), with the largest one involving 25 nodes and 150 edges. The detected isomorphic node groups, sorted by decreasing size, are:</p><ol class="medium-columns"><li><p class="paragraph">Group with 25 nodes (degree 6 and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>): <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:73103' target='_blank' title='Go to CHEBI to get more informations about CHEBI:73103'>CHEBI:73103</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:73106' target='_blank' title='Go to CHEBI to get more informations about CHEBI:73106'>CHEBI:73106</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:73120' target='_blank' title='Go to CHEBI to get more informations about CHEBI:73120'>CHEBI:73120</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:73116' target='_blank' title='Go to CHEBI to get more informations about CHEBI:73116'>CHEBI:73116</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:73071' target='_blank' title='Go to CHEBI to get more informations about CHEBI:73071'>CHEBI:73071</a> and other 20.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 67 and node type <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a>): <a href='https://reactome.org/content/detail/R-HSA-379716' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-379716'>REACT:R-HSA-379716</a> and <a href='https://reactome.org/content/detail/R-HSA-379726' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-379726'>REACT:R-HSA-379726</a>.</p></li>
# <li><p class="paragraph">Group with 22 nodes (degree 5 and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>): <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:109745' target='_blank' title='Go to CHEBI to get more informations about CHEBI:109745'>CHEBI:109745</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:104082' target='_blank' title='Go to CHEBI to get more informations about CHEBI:104082'>CHEBI:104082</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:109841' target='_blank' title='Go to CHEBI to get more informations about CHEBI:109841'>CHEBI:109841</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:123246' target='_blank' title='Go to CHEBI to get more informations about CHEBI:123246'>CHEBI:123246</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:116217' target='_blank' title='Go to CHEBI to get more informations about CHEBI:116217'>CHEBI:116217</a> and other 17.</p></li>
# <li><p class="paragraph">Group with 11 nodes (degree 8 and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>): <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:67468' target='_blank' title='Go to CHEBI to get more informations about CHEBI:67468'>CHEBI:67468</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:67472' target='_blank' title='Go to CHEBI to get more informations about CHEBI:67472'>CHEBI:67472</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:67471' target='_blank' title='Go to CHEBI to get more informations about CHEBI:67471'>CHEBI:67471</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:67465' target='_blank' title='Go to CHEBI to get more informations about CHEBI:67465'>CHEBI:67465</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:67469' target='_blank' title='Go to CHEBI to get more informations about CHEBI:67469'>CHEBI:67469</a> and other 6.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 43 and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing|biolinkChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing|biolink:ChemicalEntity'>biolink:NamedThing|biolink:ChemicalEntity</a>): <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:60628' target='_blank' title='Go to CHEBI to get more informations about CHEBI:60628'>CHEBI:60628</a> and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:60629' target='_blank' title='Go to CHEBI to get more informations about CHEBI:60629'>CHEBI:60629</a>.</p></li>
# <li><p class="paragraph">Group with 5 nodes (degree 17 and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing|biolinkChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing|biolink:ChemicalEntity'>biolink:NamedThing|biolink:ChemicalEntity</a>): <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:180691' target='_blank' title='Go to CHEBI to get more informations about CHEBI:180691'>CHEBI:180691</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:180689' target='_blank' title='Go to CHEBI to get more informations about CHEBI:180689'>CHEBI:180689</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:180686' target='_blank' title='Go to CHEBI to get more informations about CHEBI:180686'>CHEBI:180686</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:180685' target='_blank' title='Go to CHEBI to get more informations about CHEBI:180685'>CHEBI:180685</a> and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:180684' target='_blank' title='Go to CHEBI to get more informations about CHEBI:180684'>CHEBI:180684</a>.</p></li>
# <li><p class="paragraph">Group with 5 nodes (degree 14 and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing|biolinkChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing|biolink:ChemicalEntity'>biolink:NamedThing|biolink:ChemicalEntity</a>): <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:140918' target='_blank' title='Go to CHEBI to get more informations about CHEBI:140918'>CHEBI:140918</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:140919' target='_blank' title='Go to CHEBI to get more informations about CHEBI:140919'>CHEBI:140919</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:140911' target='_blank' title='Go to CHEBI to get more informations about CHEBI:140911'>CHEBI:140911</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:140917' target='_blank' title='Go to CHEBI to get more informations about CHEBI:140917'>CHEBI:140917</a> and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:140916' target='_blank' title='Go to CHEBI to get more informations about CHEBI:140916'>CHEBI:140916</a>.</p></li>
# <li><p class="paragraph">Group with 10 nodes (degree 5 and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>): <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:68763' target='_blank' title='Go to CHEBI to get more informations about CHEBI:68763'>CHEBI:68763</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:68814' target='_blank' title='Go to CHEBI to get more informations about CHEBI:68814'>CHEBI:68814</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:68740' target='_blank' title='Go to CHEBI to get more informations about CHEBI:68740'>CHEBI:68740</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:68815' target='_blank' title='Go to CHEBI to get more informations about CHEBI:68815'>CHEBI:68815</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:68778' target='_blank' title='Go to CHEBI to get more informations about CHEBI:68778'>CHEBI:68778</a> and other 5.</p></li>
# <li><p class="paragraph">Group with 10 nodes (degree 5 and node type <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a>): <a href='https://reactome.org/content/detail/R-MMU-9013408' target='_blank' title='Go to Reactome to get more informations about REACT:R-MMU-9013408'>REACT:R-MMU-9013408</a>, <a href='https://reactome.org/content/detail/R-MMU-9013405' target='_blank' title='Go to Reactome to get more informations about REACT:R-MMU-9013405'>REACT:R-MMU-9013405</a>, <a href='https://reactome.org/content/detail/R-MMU-9013409' target='_blank' title='Go to Reactome to get more informations about REACT:R-MMU-9013409'>REACT:R-MMU-9013409</a>, <a href='https://reactome.org/content/detail/R-MMU-9035034' target='_blank' title='Go to Reactome to get more informations about REACT:R-MMU-9035034'>REACT:R-MMU-9035034</a>, <a href='https://reactome.org/content/detail/R-MMU-8980692' target='_blank' title='Go to Reactome to get more informations about REACT:R-MMU-8980692'>REACT:R-MMU-8980692</a> and other 5.</p></li>
# <li><p class="paragraph">Group with 10 nodes (degree 5 and node type <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a>): <a href='https://reactome.org/content/detail/R-HSA-8980692' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-8980692'>REACT:R-HSA-8980692</a>, <a href='https://reactome.org/content/detail/R-HSA-9013406' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-9013406'>REACT:R-HSA-9013406</a>, <a href='https://reactome.org/content/detail/R-HSA-9013405' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-9013405'>REACT:R-HSA-9013405</a>, <a href='https://reactome.org/content/detail/R-HSA-9013106' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-9013106'>REACT:R-HSA-9013106</a>, <a href='https://reactome.org/content/detail/R-HSA-9013404' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-9013404'>REACT:R-HSA-9013404</a> and other 5.</p></li>
# <li><p class="paragraph">Group with 10 nodes (degree 5 and node type <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a>): <a href='https://reactome.org/content/detail/R-RNO-8980692' target='_blank' title='Go to Reactome to get more informations about REACT:R-RNO-8980692'>REACT:R-RNO-8980692</a>, <a href='https://reactome.org/content/detail/R-RNO-9013026' target='_blank' title='Go to Reactome to get more informations about REACT:R-RNO-9013026'>REACT:R-RNO-9013026</a>, <a href='https://reactome.org/content/detail/R-RNO-9035034' target='_blank' title='Go to Reactome to get more informations about REACT:R-RNO-9035034'>REACT:R-RNO-9035034</a>, <a href='https://reactome.org/content/detail/R-RNO-9013404' target='_blank' title='Go to Reactome to get more informations about REACT:R-RNO-9013404'>REACT:R-RNO-9013404</a>, <a href='https://reactome.org/content/detail/R-RNO-9013106' target='_blank' title='Go to Reactome to get more informations about REACT:R-RNO-9013106'>REACT:R-RNO-9013106</a> and other 5.</p></li>
# <li><p class="paragraph">Group with 10 nodes (degree 5 and node type <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a>): <a href='https://reactome.org/content/detail/R-GGA-9013409' target='_blank' title='Go to Reactome to get more informations about REACT:R-GGA-9013409'>REACT:R-GGA-9013409</a>, <a href='https://reactome.org/content/detail/R-GGA-9013408' target='_blank' title='Go to Reactome to get more informations about REACT:R-GGA-9013408'>REACT:R-GGA-9013408</a>, <a href='https://reactome.org/content/detail/R-GGA-8980692' target='_blank' title='Go to Reactome to get more informations about REACT:R-GGA-8980692'>REACT:R-GGA-8980692</a>, <a href='https://reactome.org/content/detail/R-GGA-9013106' target='_blank' title='Go to Reactome to get more informations about REACT:R-GGA-9013106'>REACT:R-GGA-9013106</a>, <a href='https://reactome.org/content/detail/R-GGA-9013404' target='_blank' title='Go to Reactome to get more informations about REACT:R-GGA-9013404'>REACT:R-GGA-9013404</a> and other 5.</p></li>
# <li><p class="paragraph">Group with 10 nodes (degree 5 and node type <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a>): <a href='https://reactome.org/content/detail/R-SSC-9013026' target='_blank' title='Go to Reactome to get more informations about REACT:R-SSC-9013026'>REACT:R-SSC-9013026</a>, <a href='https://reactome.org/content/detail/R-SSC-9013106' target='_blank' title='Go to Reactome to get more informations about REACT:R-SSC-9013106'>REACT:R-SSC-9013106</a>, <a href='https://reactome.org/content/detail/R-SSC-9013408' target='_blank' title='Go to Reactome to get more informations about REACT:R-SSC-9013408'>REACT:R-SSC-9013408</a>, <a href='https://reactome.org/content/detail/R-SSC-9013404' target='_blank' title='Go to Reactome to get more informations about REACT:R-SSC-9013404'>REACT:R-SSC-9013404</a>, <a href='https://reactome.org/content/detail/R-SSC-9013406' target='_blank' title='Go to Reactome to get more informations about REACT:R-SSC-9013406'>REACT:R-SSC-9013406</a> and other 5.</p></li>
# <li><p class="paragraph">Group with 3 nodes (degree 16 and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing|biolinkChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing|biolink:ChemicalEntity'>biolink:NamedThing|biolink:ChemicalEntity</a>): <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:180690' target='_blank' title='Go to CHEBI to get more informations about CHEBI:180690'>CHEBI:180690</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:180688' target='_blank' title='Go to CHEBI to get more informations about CHEBI:180688'>CHEBI:180688</a> and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:180687' target='_blank' title='Go to CHEBI to get more informations about CHEBI:180687'>CHEBI:180687</a>.</p></li>
# <li><p class="paragraph">Group with 6 nodes (degree 8 and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>): <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:67504' target='_blank' title='Go to CHEBI to get more informations about CHEBI:67504'>CHEBI:67504</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:67503' target='_blank' title='Go to CHEBI to get more informations about CHEBI:67503'>CHEBI:67503</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:67502' target='_blank' title='Go to CHEBI to get more informations about CHEBI:67502'>CHEBI:67502</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:67501' target='_blank' title='Go to CHEBI to get more informations about CHEBI:67501'>CHEBI:67501</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:67500' target='_blank' title='Go to CHEBI to get more informations about CHEBI:67500'>CHEBI:67500</a> and another one.</p></li></ol><p class="paragraph">And other 740 isomorphic node groups.</p><h4 style="margin: 1em 0 0 0;">Dendritic trees</h4><p class="paragraph">A dendritic tree is a tree-like structure starting from a root node that is part of another strongly connected component. We have detected 133 dendritic trees in the graph, involving a total of 907 nodes (0.39%) and 907 edges (0.07%), with the largest one involving 35 nodes and 35 edges. The detected dendritic trees, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Dendritic tree starting from the root node <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:29108' target='_blank' title='Go to CHEBI to get more informations about CHEBI:29108'>CHEBI:29108</a> (degree 1.27K), and containing 35 nodes, with a maximal depth of 5, which are <a href='https://reactome.org/content/detail/R-XTR-418990' target='_blank' title='Go to Reactome to get more informations about REACT:R-XTR-418990'>REACT:R-XTR-418990</a> (degree 3), <a href='https://reactome.org/content/detail/R-PFA-5578775' target='_blank' title='Go to Reactome to get more informations about REACT:R-PFA-5578775'>REACT:R-PFA-5578775</a>, <a href='https://reactome.org/content/detail/R-SPO-5578775' target='_blank' title='Go to Reactome to get more informations about REACT:R-SPO-5578775'>REACT:R-SPO-5578775</a>, <a href='https://reactome.org/content/detail/R-BTA-418990' target='_blank' title='Go to Reactome to get more informations about REACT:R-BTA-418990'>REACT:R-BTA-418990</a> (degree 3) and <a href='https://reactome.org/content/detail/R-GGA-418990' target='_blank' title='Go to Reactome to get more informations about REACT:R-GGA-418990'>REACT:R-GGA-418990</a> (degree 3). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a>.</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/FOODON_03460238' target='_blank' title='Go to FOODON to get more informations about FOODON:03460238'>FOODON:03460238</a> (degree 20), and containing 25 nodes, with a maximal depth of 3, which are <a href='http://purl.obolibrary.org/obo/FOODON_03460134' target='_blank' title='Go to FOODON to get more informations about FOODON:03460134'>FOODON:03460134</a>, <a href='http://purl.obolibrary.org/obo/FOODON_03460137' target='_blank' title='Go to FOODON to get more informations about FOODON:03460137'>FOODON:03460137</a>, <a href='http://purl.obolibrary.org/obo/FOODON_00003215' target='_blank' title='Go to FOODON to get more informations about FOODON:00003215'>FOODON:00003215</a>, <a href='http://purl.obolibrary.org/obo/FOODON_03460198' target='_blank' title='Go to FOODON to get more informations about FOODON:03460198'>FOODON:03460198</a> and <a href='http://purl.obolibrary.org/obo/FOODON_00003307' target='_blank' title='Go to FOODON to get more informations about FOODON:00003307'>FOODON:00003307</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>.</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:4705' target='_blank' title='Go to CHEBI to get more informations about CHEBI:4705'>CHEBI:4705</a> (degree 180), and containing 24 nodes, with a maximal depth of 6, which are <a href='https://reactome.org/content/detail/R-CEL-140342' target='_blank' title='Go to Reactome to get more informations about REACT:R-CEL-140342'>REACT:R-CEL-140342</a>, <a href='https://reactome.org/content/detail/R-PFA-140342' target='_blank' title='Go to Reactome to get more informations about REACT:R-PFA-140342'>REACT:R-PFA-140342</a>, <a href='https://reactome.org/content/detail/R-CEL-75153' target='_blank' title='Go to Reactome to get more informations about REACT:R-CEL-75153'>REACT:R-CEL-75153</a> (degree 3), <a href='https://reactome.org/content/detail/R-PFA-75153' target='_blank' title='Go to Reactome to get more informations about REACT:R-PFA-75153'>REACT:R-PFA-75153</a> and <a href='https://reactome.org/content/detail/R-CEL-109581' target='_blank' title='Go to Reactome to get more informations about REACT:R-CEL-109581'>REACT:R-CEL-109581</a> (degree 4). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a>.</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='https://reactome.org/content/detail/R-HSA-1643685' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-1643685'>REACT:R-HSA-1643685</a> (degree 12), and containing 21 nodes, with a maximal depth of 5, which are <a href='https://reactome.org/content/detail/R-HSA-9675132' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-9675132'>REACT:R-HSA-9675132</a>, <a href='https://reactome.org/content/detail/R-HSA-9675126' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-9675126'>REACT:R-HSA-9675126</a> (degree 3), <a href='https://reactome.org/content/detail/R-HSA-9630747' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-9630747'>REACT:R-HSA-9630747</a> (degree 5), <a href='https://reactome.org/content/detail/R-HSA-9673013' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-9673013'>REACT:R-HSA-9673013</a> and <a href='https://reactome.org/content/detail/R-HSA-9687139' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-9687139'>REACT:R-HSA-9687139</a> (degree 3). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a>.</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/FOODON_03460130' target='_blank' title='Go to FOODON to get more informations about FOODON:03460130'>FOODON:03460130</a> (degree 31), and containing 19 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/FOODON_03460178' target='_blank' title='Go to FOODON to get more informations about FOODON:03460178'>FOODON:03460178</a> (degree 3), <a href='http://purl.obolibrary.org/obo/FOODON_03460276' target='_blank' title='Go to FOODON to get more informations about FOODON:03460276'>FOODON:03460276</a>, <a href='http://purl.obolibrary.org/obo/FOODON_03460781' target='_blank' title='Go to FOODON to get more informations about FOODON:03460781'>FOODON:03460781</a>, <a href='http://purl.obolibrary.org/obo/FOODON_03460174' target='_blank' title='Go to FOODON to get more informations about FOODON:03460174'>FOODON:03460174</a> and <a href='http://purl.obolibrary.org/obo/FOODON_03460306' target='_blank' title='Go to FOODON to get more informations about FOODON:03460306'>FOODON:03460306</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>.</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='https://reactome.org/content/detail/R-DME-449147' target='_blank' title='Go to Reactome to get more informations about REACT:R-DME-449147'>REACT:R-DME-449147</a> (degree 12), and containing 18 nodes, with a maximal depth of 2, which are <a href='https://reactome.org/content/detail/R-DME-512988' target='_blank' title='Go to Reactome to get more informations about REACT:R-DME-512988'>REACT:R-DME-512988</a>, <a href='https://reactome.org/content/detail/R-DME-6783783' target='_blank' title='Go to Reactome to get more informations about REACT:R-DME-6783783'>REACT:R-DME-6783783</a>, <a href='https://reactome.org/content/detail/R-DME-6785807' target='_blank' title='Go to Reactome to get more informations about REACT:R-DME-6785807'>REACT:R-DME-6785807</a>, <a href='https://reactome.org/content/detail/R-DME-449836' target='_blank' title='Go to Reactome to get more informations about REACT:R-DME-449836'>REACT:R-DME-449836</a> and <a href='https://reactome.org/content/detail/R-DME-8854691' target='_blank' title='Go to Reactome to get more informations about REACT:R-DME-8854691'>REACT:R-DME-8854691</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a>.</p></li></ol><p class="paragraph">And other 127 dendritic trees.</p><h4 style="margin: 1em 0 0 0;">Stars</h4><p class="paragraph">A star is a tree with a maximal depth of one, where nodes with maximal unique degree one are connected to a central root node with a high degree. We have detected 9 stars in the graph, involving a total of 38 nodes (0.02%) and 29 edges, with the largest one involving 5 nodes and 4 edges. The detected stars, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Star starting from the root node <a href='http://www.geneontology.org/formats/oboInOwl#hasSynonym' target='_blank' title='Go to Gene Ontology OBO in OWL to get more informations about OIO:hasSynonym'>OIO:hasSynonym</a> (degree 4), and containing 5 nodes, with a maximal depth of 1, which are <a href='http://www.geneontology.org/formats/oboInOwl#hasBroadSynonym' target='_blank' title='Go to Gene Ontology OBO in OWL to get more informations about OIO:hasBroadSynonym'>OIO:hasBroadSynonym</a>, <a href='http://www.geneontology.org/formats/oboInOwl#hasNarrowSynonym' target='_blank' title='Go to Gene Ontology OBO in OWL to get more informations about OIO:hasNarrowSynonym'>OIO:hasNarrowSynonym</a>, <a href='http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym' target='_blank' title='Go to Gene Ontology OBO in OWL to get more informations about OIO:hasRelatedSynonym'>OIO:hasRelatedSynonym</a> and <a href='http://www.geneontology.org/formats/oboInOwl#hasExactSynonym' target='_blank' title='Go to Gene Ontology OBO in OWL to get more informations about OIO:hasExactSynonym'>OIO:hasExactSynonym</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>.</p></li>
# <li><p class="paragraph">Star starting from the root node <a href='https://reactome.org/content/detail/R-SCE-9609507' target='_blank' title='Go to Reactome to get more informations about REACT:R-SCE-9609507'>REACT:R-SCE-9609507</a> (degree 4), and containing 5 nodes, with a maximal depth of 1, which are <a href='https://reactome.org/content/detail/R-SCE-9609523' target='_blank' title='Go to Reactome to get more informations about REACT:R-SCE-9609523'>REACT:R-SCE-9609523</a>, <a href='https://reactome.org/content/detail/R-SCE-9603798' target='_blank' title='Go to Reactome to get more informations about REACT:R-SCE-9603798'>REACT:R-SCE-9603798</a>, <a href='https://reactome.org/content/detail/R-SCE-1268020' target='_blank' title='Go to Reactome to get more informations about REACT:R-SCE-1268020'>REACT:R-SCE-1268020</a> and <a href='https://reactome.org/content/detail/R-SCE-9033241' target='_blank' title='Go to Reactome to get more informations about REACT:R-SCE-9033241'>REACT:R-SCE-9033241</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a>.</p></li>
# <li><p class="paragraph">Star starting from the root node <a href='https://reactome.org/content/detail/R-SPO-9609507' target='_blank' title='Go to Reactome to get more informations about REACT:R-SPO-9609507'>REACT:R-SPO-9609507</a> (degree 4), and containing 5 nodes, with a maximal depth of 1, which are <a href='https://reactome.org/content/detail/R-SPO-9033241' target='_blank' title='Go to Reactome to get more informations about REACT:R-SPO-9033241'>REACT:R-SPO-9033241</a>, <a href='https://reactome.org/content/detail/R-SPO-9609523' target='_blank' title='Go to Reactome to get more informations about REACT:R-SPO-9609523'>REACT:R-SPO-9609523</a>, <a href='https://reactome.org/content/detail/R-SPO-9603798' target='_blank' title='Go to Reactome to get more informations about REACT:R-SPO-9603798'>REACT:R-SPO-9603798</a> and <a href='https://reactome.org/content/detail/R-SPO-1268020' target='_blank' title='Go to Reactome to get more informations about REACT:R-SPO-1268020'>REACT:R-SPO-1268020</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a>.</p></li>
# <li><p class="paragraph">Star starting from the root node <a href='https://reactome.org/content/detail/R-CEL-9609507' target='_blank' title='Go to Reactome to get more informations about REACT:R-CEL-9609507'>REACT:R-CEL-9609507</a> (degree 4), and containing 5 nodes, with a maximal depth of 1, which are <a href='https://reactome.org/content/detail/R-CEL-9609523' target='_blank' title='Go to Reactome to get more informations about REACT:R-CEL-9609523'>REACT:R-CEL-9609523</a>, <a href='https://reactome.org/content/detail/R-CEL-1268020' target='_blank' title='Go to Reactome to get more informations about REACT:R-CEL-1268020'>REACT:R-CEL-1268020</a>, <a href='https://reactome.org/content/detail/R-CEL-9603798' target='_blank' title='Go to Reactome to get more informations about REACT:R-CEL-9603798'>REACT:R-CEL-9603798</a> and <a href='https://reactome.org/content/detail/R-CEL-9033241' target='_blank' title='Go to Reactome to get more informations about REACT:R-CEL-9033241'>REACT:R-CEL-9033241</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a>.</p></li>
# ...
# <li><p class="paragraph">Dendritic tendril star starting from the root node <a href='https://reactome.org/content/detail/R-BTA-1474244' target='_blank' title='Go to Reactome to get more informations about REACT:R-BTA-1474244'>REACT:R-BTA-1474244</a> (degree 7), and containing 6 nodes, with a maximal depth of 2, which are <a href='https://reactome.org/content/detail/R-BTA-3000171' target='_blank' title='Go to Reactome to get more informations about REACT:R-BTA-3000171'>REACT:R-BTA-3000171</a>, <a href='https://reactome.org/content/detail/R-BTA-3000178' target='_blank' title='Go to Reactome to get more informations about REACT:R-BTA-3000178'>REACT:R-BTA-3000178</a>, <a href='https://reactome.org/content/detail/R-BTA-216083' target='_blank' title='Go to Reactome to get more informations about REACT:R-BTA-216083'>REACT:R-BTA-216083</a>, <a href='https://reactome.org/content/detail/R-BTA-1566948' target='_blank' title='Go to Reactome to get more informations about REACT:R-BTA-1566948'>REACT:R-BTA-1566948</a> and <a href='https://reactome.org/content/detail/R-BTA-3000157' target='_blank' title='Go to Reactome to get more informations about REACT:R-BTA-3000157'>REACT:R-BTA-3000157</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a>.</p></li>
# <li><p class="paragraph">Dendritic tendril star starting from the root node <a href='https://reactome.org/content/detail/R-SSC-1266738' target='_blank' title='Go to Reactome to get more informations about REACT:R-SSC-1266738'>REACT:R-SSC-1266738</a> (degree 8), and containing 5 nodes, with a maximal depth of 3, which are <a href='https://reactome.org/content/detail/R-SSC-186712' target='_blank' title='Go to Reactome to get more informations about REACT:R-SSC-186712'>REACT:R-SSC-186712</a>, <a href='https://reactome.org/content/detail/R-SSC-381340' target='_blank' title='Go to Reactome to get more informations about REACT:R-SSC-381340'>REACT:R-SSC-381340</a>, <a href='https://reactome.org/content/detail/R-SSC-5682910' target='_blank' title='Go to Reactome to get more informations about REACT:R-SSC-5682910'>REACT:R-SSC-5682910</a>, <a href='https://reactome.org/content/detail/R-SSC-210745' target='_blank' title='Go to Reactome to get more informations about REACT:R-SSC-210745'>REACT:R-SSC-210745</a> and <a href='https://reactome.org/content/detail/R-SSC-211163' target='_blank' title='Go to Reactome to get more informations about REACT:R-SSC-211163'>REACT:R-SSC-211163</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a>.</p></li>
# <li><p class="paragraph">Dendritic tendril star starting from the root node <a href='https://reactome.org/content/detail/R-DME-199991' target='_blank' title='Go to Reactome to get more informations about REACT:R-DME-199991'>REACT:R-DME-199991</a> (degree 8), and containing 5 nodes, with a maximal depth of 4, which are <a href='https://reactome.org/content/detail/R-DME-5653656' target='_blank' title='Go to Reactome to get more informations about REACT:R-DME-5653656'>REACT:R-DME-5653656</a>, <a href='https://reactome.org/content/detail/R-DME-157858' target='_blank' title='Go to Reactome to get more informations about REACT:R-DME-157858'>REACT:R-DME-157858</a>, <a href='https://reactome.org/content/detail/R-DME-190828' target='_blank' title='Go to Reactome to get more informations about REACT:R-DME-190828'>REACT:R-DME-190828</a>, <a href='https://reactome.org/content/detail/R-DME-190873' target='_blank' title='Go to Reactome to get more informations about REACT:R-DME-190873'>REACT:R-DME-190873</a> and <a href='https://reactome.org/content/detail/R-DME-196025' target='_blank' title='Go to Reactome to get more informations about REACT:R-DME-196025'>REACT:R-DME-196025</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a>.</p></li>
# <li><p class="paragraph">Dendritic tendril star starting from the root node <a href='https://reactome.org/content/detail/R-SCE-199991' target='_blank' title='Go to Reactome to get more informations about REACT:R-SCE-199991'>REACT:R-SCE-199991</a> (degree 8), and containing 5 nodes, with a maximal depth of 4, which are <a href='https://reactome.org/content/detail/R-SCE-5653656' target='_blank' title='Go to Reactome to get more informations about REACT:R-SCE-5653656'>REACT:R-SCE-5653656</a>, <a href='https://reactome.org/content/detail/R-SCE-157858' target='_blank' title='Go to Reactome to get more informations about REACT:R-SCE-157858'>REACT:R-SCE-157858</a>, <a href='https://reactome.org/content/detail/R-SCE-190828' target='_blank' title='Go to Reactome to get more informations about REACT:R-SCE-190828'>REACT:R-SCE-190828</a>, <a href='https://reactome.org/content/detail/R-SCE-190873' target='_blank' title='Go to Reactome to get more informations about REACT:R-SCE-190873'>REACT:R-SCE-190873</a> and <a href='https://reactome.org/content/detail/R-SCE-196025' target='_blank' title='Go to Reactome to get more informations about REACT:R-SCE-196025'>REACT:R-SCE-196025</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a>.</p></li></ol><p class="paragraph">And other 41 dendritic tendril stars.</p><h4 style="margin: 1em 0 0 0;">Tendrils</h4><p class="paragraph">A tendril is a path starting from a node of degree one, connected to a strongly connected component. We have detected 3.79K tendrils in the graph, involving a total of 3.92K nodes (1.68%) and 3.92K edges (0.28%), with the largest one involving 4 nodes and 4 edges. The detected tendrils, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Tendril starting from the root node <a href='https://reactome.org/content/detail/R-SCE-162582' target='_blank' title='Go to Reactome to get more informations about REACT:R-SCE-162582'>REACT:R-SCE-162582</a> (degree 11), and containing 4 nodes, with a maximal depth of 4, which are <a href='https://reactome.org/content/detail/R-SCE-73887' target='_blank' title='Go to Reactome to get more informations about REACT:R-SCE-73887'>REACT:R-SCE-73887</a>, <a href='https://reactome.org/content/detail/R-SCE-193704' target='_blank' title='Go to Reactome to get more informations about REACT:R-SCE-193704'>REACT:R-SCE-193704</a>, <a href='https://reactome.org/content/detail/R-SCE-204998' target='_blank' title='Go to Reactome to get more informations about REACT:R-SCE-204998'>REACT:R-SCE-204998</a> and <a href='https://reactome.org/content/detail/R-SCE-193648' target='_blank' title='Go to Reactome to get more informations about REACT:R-SCE-193648'>REACT:R-SCE-193648</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://reactome.org/content/detail/R-PFA-162582' target='_blank' title='Go to Reactome to get more informations about REACT:R-PFA-162582'>REACT:R-PFA-162582</a> (degree 8), and containing 4 nodes, with a maximal depth of 4, which are <a href='https://reactome.org/content/detail/R-PFA-73887' target='_blank' title='Go to Reactome to get more informations about REACT:R-PFA-73887'>REACT:R-PFA-73887</a>, <a href='https://reactome.org/content/detail/R-PFA-193704' target='_blank' title='Go to Reactome to get more informations about REACT:R-PFA-193704'>REACT:R-PFA-193704</a>, <a href='https://reactome.org/content/detail/R-PFA-204998' target='_blank' title='Go to Reactome to get more informations about REACT:R-PFA-204998'>REACT:R-PFA-204998</a> and <a href='https://reactome.org/content/detail/R-PFA-193648' target='_blank' title='Go to Reactome to get more informations about REACT:R-PFA-193648'>REACT:R-PFA-193648</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://reactome.org/content/detail/R-SCE-1640170' target='_blank' title='Go to Reactome to get more informations about REACT:R-SCE-1640170'>REACT:R-SCE-1640170</a> (degree 3), and containing 4 nodes, with a maximal depth of 4, which are <a href='https://reactome.org/content/detail/R-SCE-73886' target='_blank' title='Go to Reactome to get more informations about REACT:R-SCE-73886'>REACT:R-SCE-73886</a>, <a href='https://reactome.org/content/detail/R-SCE-157579' target='_blank' title='Go to Reactome to get more informations about REACT:R-SCE-157579'>REACT:R-SCE-157579</a>, <a href='https://reactome.org/content/detail/R-SCE-180786' target='_blank' title='Go to Reactome to get more informations about REACT:R-SCE-180786'>REACT:R-SCE-180786</a> and <a href='https://reactome.org/content/detail/R-SCE-171319' target='_blank' title='Go to Reactome to get more informations about REACT:R-SCE-171319'>REACT:R-SCE-171319</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://reactome.org/content/detail/R-DDI-1640170' target='_blank' title='Go to Reactome to get more informations about REACT:R-DDI-1640170'>REACT:R-DDI-1640170</a> (degree 3), and containing 4 nodes, with a maximal depth of 4, which are <a href='https://reactome.org/content/detail/R-DDI-73886' target='_blank' title='Go to Reactome to get more informations about REACT:R-DDI-73886'>REACT:R-DDI-73886</a>, <a href='https://reactome.org/content/detail/R-DDI-157579' target='_blank' title='Go to Reactome to get more informations about REACT:R-DDI-157579'>REACT:R-DDI-157579</a>, <a href='https://reactome.org/content/detail/R-DDI-180786' target='_blank' title='Go to Reactome to get more informations about REACT:R-DDI-180786'>REACT:R-DDI-180786</a> and <a href='https://reactome.org/content/detail/R-DDI-171319' target='_blank' title='Go to Reactome to get more informations about REACT:R-DDI-171319'>REACT:R-DDI-171319</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://reactome.org/content/detail/R-SSC-597592' target='_blank' title='Go to Reactome to get more informations about REACT:R-SSC-597592'>REACT:R-SSC-597592</a> (degree 12), and containing 3 nodes, with a maximal depth of 3, which are <a href='https://reactome.org/content/detail/R-SSC-2990846' target='_blank' title='Go to Reactome to get more informations about REACT:R-SSC-2990846'>REACT:R-SSC-2990846</a>, <a href='https://reactome.org/content/detail/R-SSC-3215018' target='_blank' title='Go to Reactome to get more informations about REACT:R-SSC-3215018'>REACT:R-SSC-3215018</a> and <a href='https://reactome.org/content/detail/R-SSC-3065679' target='_blank' title='Go to Reactome to get more informations about REACT:R-SSC-3065679'>REACT:R-SSC-3065679</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='http://purl.obolibrary.org/obo/FOODON_00001102' target='_blank' title='Go to FOODON to get more informations about FOODON:00001102'>FOODON:00001102</a> (degree 5), and containing 3 nodes, with a maximal depth of 3, which are <a href='http://purl.obolibrary.org/obo/FOODON_00001019' target='_blank' title='Go to FOODON to get more informations about FOODON:00001019'>FOODON:00001019</a>, <a href='http://purl.obolibrary.org/obo/FOODON_00001020' target='_blank' title='Go to FOODON to get more informations about FOODON:00001020'>FOODON:00001020</a> and <a href='http://purl.obolibrary.org/obo/FOODON_00001021' target='_blank' title='Go to FOODON to get more informations about FOODON:00001021'>FOODON:00001021</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>.</p></li></ol><p class="paragraph">And other 3.78K tendrils.</p></div>

# %% [markdown]
# Great, now we've loaded a graph and have some general ideas about its contents.
#
# We can retrieve the total count of connected nodes (i.e., exclude all disconnected nodes from the count):

# %%
a_big_graph.get_number_of_connected_nodes()
# Out:
# 232544

# %% [markdown]
# We can also retrieve a random array of nodes to work with:

# %%
# This will output a numpy array.
# Set random_state to a specific value to get the same result reproducibly
random_int = random.randint(10000,99999)
some_nodes = a_big_graph.get_sorted_unique_random_nodes(number_of_nodes_to_sample=10, random_state=random_int)
some_nodes
# Out:
# array([ 15841,  27226,  61210,  88689, 114986, 138832, 157016, 163569,
#        209045, 222410], dtype=uint32)

# %% [markdown]
# The nodes are represented as integers for the sake of efficiency. If you'd prefer names, we can get those too:

# %%
all_node_names = []
for node_id in some_nodes:
    node_name = a_big_graph.get_node_name_from_node_id(node_id)
    all_node_names.append((node_id,node_name))
all_node_names
# Out:
# [(15841, 'CHEBI:174346'),
#  (27226, 'FOODON:03307069'),
#  (61210, 'CHEBI:57268'),
#  (88689, 'CHEBI:77910'),
#  (114986, 'FOODON:03302184'),
#  (138832, 'REACT:R-RNO-416993'),
#  (157016, 'CHEBI:70601'),
#  (163569, 'CHEBI:111383'),
#  (209045, 'CHEBI:178705'),
#  (222410, 'CHEBI:184825')]

# %% [markdown]
# We can see how many neighbors each node has (i.e., its degree):

# %%
all_node_degrees = []
for node_id in some_nodes:
    node_degree = a_big_graph.get_node_degree_from_node_id(node_id)
    all_node_degrees.append((node_id,node_degree))
all_node_degrees
# Out:
# [(15841, 2),
#  (27226, 2),
#  (61210, 3),
#  (88689, 4),
#  (114986, 2),
#  (138832, 7),
#  (157016, 3),
#  (163569, 3),
#  (209045, 2),
#  (222410, 2)]

# %% [markdown]
# We may also retrieve node types, starting with the node ID numbers:

# %%
all_node_types = []
for node_id in some_nodes:
    one_node_type = a_big_graph.get_node_type_names_from_node_id(node_id)
    if one_node_type not in all_node_types:
        all_node_types.append(one_node_type)
all_node_types
# Out:
# [['biolink:NamedThing'],
#  ['biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway']]

# %% [markdown]
# One node may have multiple node types, delimited by pipe characters.
#
# Finally, let's complete a task in preparation for the next section: assembling holdout data and sets of negative edges.

# %%
# Generate and save an 80/20 training/validation split of the edges in the input graph.
train_edge_path = merged_edge_filename + ".train"
valid_edge_path = merged_edge_filename + ".valid"

train_edge_graph, valid_edge_graph = a_big_graph.random_holdout(train_size=0.8)
train_edge_graph.dump_edges(train_edge_path, edge_type_column='predicate')
valid_edge_graph.dump_edges(valid_edge_path, edge_type_column='predicate')

# %%
# Now the graph of negatives.
negative_graph = a_big_graph.sample_negative_graph(a_big_graph.get_number_of_edges()) # Just as many negative examples as positive examples
negative_graph = negative_graph.remove_disconnected_nodes()
negative_graph
# Out:
# <div class="graph-report"><style>.graph-report li {margin: 0.5em 0 0.5em 0;}.graph-report .paragraph {text-align: justify;word-break: break-all;}.graph-report .small-columns {column-count: 4;column-gap: 2em;}.graph-report .medium-columns {column-count: 3;column-gap: 2em;}.graph-report .large-columns {column-count: 2;column-gap: 2em;}.graph-report .single-column {}@media only screen and (max-width: 600px) {.graph-report .small-columns {column-count: 1;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 600px) and (max-width: 800px) {.graph-report .small-columns {column-count: 2;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 800px) and (max-width: 1024px) {.graph-report .small-columns {column-count: 3;}.graph-report .medium-columns {column-count: 2;}.graph-report .large-columns {column-count: 1;}}</style><h2>Negative A_Big_Graph</h2><p class="paragraph">The undirected graph Negative A_Big_Graph has 217.15K heterogeneous nodes and 695.51K edges. The graph contains 429 connected components, with the largest one containing 216.28K nodes and the smallest one containing 2 nodes. The RAM requirements for the nodes and edges data structures are 21.35MB and 3.02MB respectively.</p><h3 style="margin: 1em 0 0 0;">Degree centrality</h3><p class="paragraph">The minimum node degree is 1, the maximum node degree is 41.07K, the mode degree is 2, the mean degree is 6.41 and the node degree median is 3.</p><p class="paragraph">The nodes with the highest degree centrality are <a href='http://purl.obolibrary.org/obo/chebi#2_STAR' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:chebi#2_STAR'>OBO:chebi#2_STAR</a> (degree 41.07K and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='http://purl.obolibrary.org/obo/chebi#3_STAR' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:chebi#3_STAR'>OBO:chebi#3_STAR</a> (degree 23.52K and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='http://purl.obolibrary.org/obo/IAO_0000428' target='_blank' title='Go to Information Artifact Ontology to get more informations about IAO:0000428'>IAO:0000428</a> (degree 14.14K and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='http://purl.obolibrary.org/obo/IAO_0000227' target='_blank' title='Go to Information Artifact Ontology to get more informations about IAO:0000227'>IAO:0000227</a> (degree 13.81K and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:24995' target='_blank' title='Go to CHEBI to get more informations about CHEBI:24995'>CHEBI:24995</a> (degree 6.08K and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p><h3 style="margin: 1em 0 0 0;">Node types</h3><p class="paragraph">The graph has 3 node types, which are <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a> (194.52K nodes, 89.58%), <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess| ...
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:21436' target='_blank' title='Go to CHEBI to get more informations about CHEBI:21436'>CHEBI:21436</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/FOODON_03543492' target='_blank' title='Go to FOODON to get more informations about FOODON:03543492'>FOODON:03543492</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:111615' target='_blank' title='Go to CHEBI to get more informations about CHEBI:111615'>CHEBI:111615</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='https://www.ecfr.gov/cgi-bin/retrieveECFR?gp=&SID=6c20aac2cb53eede54e8b44bbb0fea53&mc=true&n=pt21.2.169&r=PART&ty=HTML#se21.2.169_1115' target='_blank' title='Go to website to get more informations about https:&#x2f;&#x2f;www.ecfr.gov&#x2f;cgi-bin&#x2f;retrieveECFR?gp=&amp;SID=6c20aac2cb53eede54e8b44bbb0fea53&amp;mc=true&amp;n=pt21.2.169&amp;r=PART&amp;ty=HTML#se21.2.169_1115'>https:&#x2f;&#x2f;www.ecfr.gov&#x2f;cgi-bin&#x2f;retrieveECFR?gp=&amp;SID=6c20aac2cb53eede54e8b44bbb0fea53&amp;mc=true&amp;n=pt21.2.169&amp;r=PART&amp;ty=HTML#se21.2.169_1115</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:122054' target='_blank' title='Go to CHEBI to get more informations about CHEBI:122054'>CHEBI:122054</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:169237' target='_blank' title='Go to CHEBI to get more informations about CHEBI:169237'>CHEBI:169237</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:121804' target='_blank' title='Go to CHEBI to get more informations about CHEBI:121804'>CHEBI:121804</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:122494' target='_blank' title='Go to CHEBI to get more informations about CHEBI:122494'>CHEBI:122494</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:150092' target='_blank' title='Go to CHEBI to get more informations about CHEBI:150092'>CHEBI:150092</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:159253' target='_blank' title='Go to CHEBI to get more informations about CHEBI:159253'>CHEBI:159253</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:45140' target='_blank' title='Go to CHEBI to get more informations about CHEBI:45140'>CHEBI:45140</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:638' target='_blank' title='Go to CHEBI to get more informations about CHEBI:638'>CHEBI:638</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:152132' target='_blank' title='Go to CHEBI to get more informations about CHEBI:152132'>CHEBI:152132</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:107874' target='_blank' title='Go to CHEBI to get more informations about CHEBI:107874'>CHEBI:107874</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:113286' target='_blank' title='Go to CHEBI to get more informations about CHEBI:113286'>CHEBI:113286</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:59470' target='_blank' title='Go to CHEBI to get more informations about CHEBI:59470'>CHEBI:59470</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:162696' target='_blank' title='Go to CHEBI to get more informations about CHEBI:162696'>CHEBI:162696</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:99438' target='_blank' title='Go to CHEBI to get more informations about CHEBI:99438'>CHEBI:99438</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/FOODON_03310564' target='_blank' title='Go to FOODON to get more informations about FOODON:03310564'>FOODON:03310564</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:13845' target='_blank' title='Go to CHEBI to get more informations about CHEBI:13845'>CHEBI:13845</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/FOODON_03412590' target='_blank' title='Go to FOODON to get more informations about FOODON:03412590'>FOODON:03412590</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:187026' target='_blank' title='Go to CHEBI to get more informations about CHEBI:187026'>CHEBI:187026</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=5302' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:5302'>NCBITaxon:5302</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/FOODON_03401214' target='_blank' title='Go to FOODON to get more informations about FOODON:03401214'>FOODON:03401214</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:23879' target='_blank' title='Go to CHEBI to get more informations about CHEBI:23879'>CHEBI:23879</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:152801' target='_blank' title='Go to CHEBI to get more informations about CHEBI:152801'>CHEBI:152801</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:29520' target='_blank' title='Go to CHEBI to get more informations about CHEBI:29520'>CHEBI:29520</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='https://reactome.org/content/detail/R-CEL-9020591' target='_blank' title='Go to Reactome to get more informations about REACT:R-CEL-9020591'>REACT:R-CEL-9020591</a> (node type <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a>).</p></li></ul><p class="paragraph">And other 394 node tuples.</p><h4 style="margin: 1em 0 0 0;">Dendritic trees</h4><p class="paragraph">A dendritic tree is a tree-like structure starting from a root node that is part of another strongly connected component. We have detected 172 dendritic trees in the graph, involving a total of 8.39K nodes (3.87%) and 8.39K edges (0.60%), with the largest one involving 1.68K nodes and 1.68K edges. The detected dendritic trees, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/chebi#3_STAR' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:chebi#3_STAR'>OBO:chebi#3_STAR</a> (degree 23.52K and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), and containing 1.68K nodes, with a maximal depth of 3, which are <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:103722' target='_blank' title='Go to CHEBI to get more informations about CHEBI:103722'>CHEBI:103722</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:107718' target='_blank' title='Go to CHEBI to get more informations about CHEBI:107718'>CHEBI:107718</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:77749' target='_blank' title='Go to CHEBI to get more informations about CHEBI:77749'>CHEBI:77749</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:117085' target='_blank' title='Go to CHEBI to get more informations about CHEBI:117085'>CHEBI:117085</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:101331' target='_blank' title='Go to CHEBI to get more informations about CHEBI:101331'>CHEBI:101331</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>). Its nodes have 2 node types, which are <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' targe ...
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/chebi#2_STAR' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:chebi#2_STAR'>OBO:chebi#2_STAR</a> (degree 41.07K and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), and containing 1.34K nodes, with a maximal depth of 4, which are <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:84354' target='_blank' title='Go to CHEBI to get more informations about CHEBI:84354'>CHEBI:84354</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:88076' target='_blank' title='Go to CHEBI to get more informations about CHEBI:88076'>CHEBI:88076</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:134349' target='_blank' title='Go to CHEBI to get more informations about CHEBI:134349'>CHEBI:134349</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:90113' target='_blank' title='Go to CHEBI to get more informations about CHEBI:90113'>CHEBI:90113</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:65890' target='_blank' title='Go to CHEBI to get more informations about CHEBI:65890'>CHEBI:65890</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>). Its nodes have 2 node types, which are <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a> (1.16K nodes, 0.54%) and <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a> (174 nodes, 0.08%).</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/IAO_0000428' target='_blank' title='Go to Information Artifact Ontology to get more informations about IAO:0000428'>IAO:0000428</a> (degree 14.14K and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), and containing 516 nodes, with a maximal depth of 3, which are <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:94392' target='_blank' title='Go to CHEBI to get more informations about CHEBI:94392'>CHEBI:94392</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:107161' target='_blank' title='Go to CHEBI to get more informations about CHEBI:107161'>CHEBI:107161</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:143458' target='_blank' title='Go to CHEBI to get more informations about CHEBI:143458'>CHEBI:143458</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:63291' target='_blank' title='Go to CHEBI to get more informations about CHEBI:63291'>CHEBI:63291</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:160700' target='_blank' title='Go to CHEBI to get more informations about CHEBI:160700'>CHEBI:160700</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>). Its nodes have 2 node types, which are <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a> (485 nodes, 0.22%) and <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a> (31 nodes, 0.01%).</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/IAO_0000227' target='_blank' title='Go to Information Artifact Ontology to get more informations about IAO:0000227'>IAO:0000227</a> (degree 13.81K and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), and containing 464 nodes, with a maximal depth of 3, which are <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:149673' target='_blank' title='Go to CHEBI to get more informations about CHEBI:149673'>CHEBI:149673</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:71671' target='_blank' title='Go to CHEBI to get more informations about CHEBI:71671'>CHEBI:71671</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:158051' target='_blank' title='Go to CHEBI to get more informations about CHEBI:158051'>CHEBI:158051</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:122040' target='_blank' title='Go to CHEBI to get more informations about CHEBI:122040'>CHEBI:122040</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:174789' target='_blank' title='Go to CHEBI to get more informations about CHEBI:174789'>CHEBI:174789</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>). Its nodes have 2 node types, which are <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a> (432 nodes, 0.20%) and <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a> (32 nodes, 0.01%).</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:52898' target='_blank' title='Go to CHEBI to get more informations about CHEBI:52898'>CHEBI:52898</a> (degree 5.86K and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), and containing 217 nodes, with a maximal depth of 2, which are <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:29880' target='_blank' title='Go to CHEBI to get more informations about CHEBI:29880'>CHEBI:29880</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:67577' target='_blank' title='Go to CHEBI to get more informations about CHEBI:67577'>CHEBI:67577</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:146257' target='_blank' title='Go to CHEBI to get more informations about CHEBI:146257'>CHEBI:146257</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:188357' target='_blank' title='Go to CHEBI to get more informations about CHEBI:188357'>CHEBI:188357</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:102761' target='_blank' title='Go to CHEBI to get more informations about CHEBI:102761'>CHEBI:102761</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>). Its nodes have 2 node types, which are <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a> (195 nodes, 0.09%) and <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a> (22 nodes, 0.01%).</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:24995' target='_blank' title='Go to CHEBI to get more informations about CHEBI:24995'>CHEBI:24995</a> (degree 6.08K and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), and containing 209 nodes, with a maximal depth of 3, which are <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:140724' target='_blank' title='Go to CHEBI to get more informations about CHEBI:140724'>CHEBI:140724</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:159538' target='_blank' title='Go to CHEBI to get more informations about CHEBI:159538'>CHEBI:159538</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:145891' target='_blank' title='Go to CHEBI to get more informations about CHEBI:145891'>CHEBI:145891</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:189211' target='_blank' title='Go to CHEBI to get more informations about CHEBI:189211'>CHEBI:189211</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:58764' target='_blank' title='Go to CHEBI to get more informations about CHEBI:58764'>CHEBI:58764</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>). Its nodes have 2 node types, which are <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a> (198 nodes, 0.09%) and <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a> (11 nodes).</p></li></ol><p class="paragraph">And other 166 dendritic trees.</p><h4 style="margin: 1em 0 0 0;">Stars</h4><p class="paragraph">A star is a tree with a maximal depth of one, where nodes with maximal unique degree one are connected to a central root node with a high degree. We have detected 18 stars in the graph, involving a total of 54 nodes (0.02%) and 36 edges. The detected stars are:</p><ul class="large-columns"><li><p class="paragraph">Star starting from the root node <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:52398' target='_blank' title='Go to CHEBI to get more informations about CHEBI:52398'>CHEBI:52398</a> (degree 2), and containing 3 nodes, with a maximal depth of 1, which are <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:186173' target='_blank' title='Go to CHEBI to get more informations about CHEBI:186173'>CHEBI:186173</a> and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:157133' target='_blank' title='Go to CHEBI to get more i ...
# <li><p class="paragraph">Star starting from the root node <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:73334' target='_blank' title='Go to CHEBI to get more informations about CHEBI:73334'>CHEBI:73334</a> (degree 2), and containing 3 nodes, with a maximal depth of 1, which are <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:186289' target='_blank' title='Go to CHEBI to get more informations about CHEBI:186289'>CHEBI:186289</a> and <a href='http://purl.obolibrary.org/obo/FOODON_03401768' target='_blank' title='Go to FOODON to get more informations about FOODON:03401768'>FOODON:03401768</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>.</p></li>
# <li><p class="paragraph">Star starting from the root node <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:101305' target='_blank' title='Go to CHEBI to get more informations about CHEBI:101305'>CHEBI:101305</a> (degree 2), and containing 3 nodes, with a maximal depth of 1, which are <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:122436' target='_blank' title='Go to CHEBI to get more informations about CHEBI:122436'>CHEBI:122436</a> and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:108050' target='_blank' title='Go to CHEBI to get more informations about CHEBI:108050'>CHEBI:108050</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>.</p></li>
# <li><p class="paragraph">Star starting from the root node <a href='http://purl.obolibrary.org/obo/FOODON_00002512' target='_blank' title='Go to FOODON to get more informations about FOODON:00002512'>FOODON:00002512</a> (degree 2), and containing 3 nodes, with a maximal depth of 1, which are <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:143363' target='_blank' title='Go to CHEBI to get more informations about CHEBI:143363'>CHEBI:143363</a> and <a href='http://purl.obolibrary.org/obo/FOODON_00003972' target='_blank' title='Go to FOODON to get more informations about FOODON:00003972'>FOODON:00003972</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>.</p></li>
# <li><p class="paragraph">Star starting from the root node <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:149562' target='_blank' title='Go to CHEBI to get more informations about CHEBI:149562'>CHEBI:149562</a> (degree 2), and containing 3 nodes, with a maximal depth of 1, which are <a href='http://purl.obolibrary.org/obo/FOODON_03542399' target='_blank' title='Go to FOODON to get more informations about FOODON:03542399'>FOODON:03542399</a> and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:189538' target='_blank' title='Go to CHEBI to get more informations about CHEBI:189538'>CHEBI:189538</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>.</p></li>
# <li><p class="paragraph">Star starting from the root node <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:118709' target='_blank' title='Go to CHEBI to get more informations about CHEBI:118709'>CHEBI:118709</a> (degree 2), and containing 3 nodes, with a maximal depth of 1, which are <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:170958' target='_blank' title='Go to CHEBI to get more informations about CHEBI:170958'>CHEBI:170958</a> and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:183758' target='_blank' title='Go to CHEBI to get more informations about CHEBI:183758'>CHEBI:183758</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>.</p></li></ul><p class="paragraph">And other 12 stars.</p><h4 style="margin: 1em 0 0 0;">Dendritic stars</h4><p class="paragraph">A dendritic star is a dendritic tree with a maximal depth of one, where nodes with maximal unique degree one are connected to a central root node with high degree and inside a strongly connected component. We have detected 2.37K dendritic stars in the graph, involving a total of 6.86K nodes (3.16%) and 6.86K edges (0.49%), with the largest one involving 41 nodes and 41 edges. The detected dendritic stars, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Dendritic star starting from the root node <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:24400' target='_blank' title='Go to CHEBI to get more informations about CHEBI:24400'>CHEBI:24400</a> (degree 1.60K and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), and containing 41 nodes, with a maximal depth of 1, which are <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:89535' target='_blank' title='Go to CHEBI to get more informations about CHEBI:89535'>CHEBI:89535</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:38052' target='_blank' title='Go to CHEBI to get more informations about CHEBI:38052'>CHEBI:38052</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://reactome.org/content/detail/R-CFA-975574' target='_blank' title='Go to Reactome to get more informations about REACT:R-CFA-975574'>REACT:R-CFA-975574</a> (node type <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a>), <a href='http://purl.obolibrary.org/obo/FOODON_03460172' target='_blank' title='Go to FOODON to get more informations about FOODON:03460172'>FOODON:03460172</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/FOODON_00002644' target='_blank' title='Go to FOODON to get more informations about FOODON:00002644'>FOODON:00002644</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</ ...
# <li><p class="paragraph">Dendritic star starting from the root node <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:74927' target='_blank' title='Go to CHEBI to get more informations about CHEBI:74927'>CHEBI:74927</a> (degree 899 and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), and containing 29 nodes, with a maximal depth of 1, which are <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:138148' target='_blank' title='Go to CHEBI to get more informations about CHEBI:138148'>CHEBI:138148</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:125841' target='_blank' title='Go to CHEBI to get more informations about CHEBI:125841'>CHEBI:125841</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:152470' target='_blank' title='Go to CHEBI to get more informations about CHEBI:152470'>CHEBI:152470</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:117903' target='_blank' title='Go to CHEBI to get more informations about CHEBI:117903'>CHEBI:117903</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='https://reactome.org/content/detail/R-SCE-111457' target='_blank' title='Go to Reactome to get more informations about REACT:R-SCE-111457'>REACT:R-SCE-111457</a> (node type <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a>). Its nodes have 2 node types, which are <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a> (25 nodes, 0.01%) and <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a> (4 nodes).</p></li>
# ...
# <li><p class="paragraph">Dendritic tendril star starting from the root node <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:57692' target='_blank' title='Go to CHEBI to get more informations about CHEBI:57692'>CHEBI:57692</a> (degree 759 and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing|biolinkChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing|biolink:ChemicalEntity'>biolink:NamedThing|biolink:ChemicalEntity</a>), and containing 36 nodes, with a maximal depth of 2, which are <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:68471' target='_blank' title='Go to CHEBI to get more informations about CHEBI:68471'>CHEBI:68471</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:167766' target='_blank' title='Go to CHEBI to get more informations about CHEBI:167766'>CHEBI:167766</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:32143' target='_blank' title='Go to CHEBI to get more informations about CHEBI:32143'>CHEBI:32143</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:62869' target='_blank' title='Go to CHEBI to get more informations about CHEBI:62869'>CHEBI:62869</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:83579' target='_blank' title='Go to CHEBI to get more informations about CHEBI:83579'>CHEBI:83579</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>). Its nodes have 2 node types, which are <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a> (34 nodes, 0.02%) and <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcessOrActivity|biolinkBiologicalProcess|biolinkNamedThing|biolinkPathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway'>biolink:BiologicalProcessOrActivity|biolink:BiologicalProcess|biolink:NamedThing|biolink:Pathway</a> (2 nodes).</p></li>
# <li><p class="paragraph">Dendritic tendril star starting from the root node <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:38777' target='_blank' title='Go to CHEBI to get more informations about CHEBI:38777'>CHEBI:38777</a> (degree 1.41K), and containing 35 nodes, with a maximal depth of 2, which are <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:101657' target='_blank' title='Go to CHEBI to get more informations about CHEBI:101657'>CHEBI:101657</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:162986' target='_blank' title='Go to CHEBI to get more informations about CHEBI:162986'>CHEBI:162986</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:30202' target='_blank' title='Go to CHEBI to get more informations about CHEBI:30202'>CHEBI:30202</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:95448' target='_blank' title='Go to CHEBI to get more informations about CHEBI:95448'>CHEBI:95448</a> and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:96233' target='_blank' title='Go to CHEBI to get more informations about CHEBI:96233'>CHEBI:96233</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>.</p></li>
# <li><p class="paragraph">Dendritic tendril star starting from the root node <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:57540' target='_blank' title='Go to CHEBI to get more informations about CHEBI:57540'>CHEBI:57540</a> (degree 905), and containing 32 nodes, with a maximal depth of 2, which are <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:75351' target='_blank' title='Go to CHEBI to get more informations about CHEBI:75351'>CHEBI:75351</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:51226' target='_blank' title='Go to CHEBI to get more informations about CHEBI:51226'>CHEBI:51226</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:85948' target='_blank' title='Go to CHEBI to get more informations about CHEBI:85948'>CHEBI:85948</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:183848' target='_blank' title='Go to CHEBI to get more informations about CHEBI:183848'>CHEBI:183848</a> and <a href='http://purl.obolibrary.org/obo/FOODON_03412943' target='_blank' title='Go to FOODON to get more informations about FOODON:03412943'>FOODON:03412943</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>.</p></li></ol><p class="paragraph">And other 436 dendritic tendril stars.</p><h4 style="margin: 1em 0 0 0;">Free-floating chains</h4><p class="paragraph">A free-floating chain is a tree with maximal degree two. We have detected  a single free-floating chain in the graph, involving a total of 4 nodes and 3 edges.</p><ul class="large-columns"><li><p class="paragraph">Free-floating chain starting from the root node <a href='http://purl.obolibrary.org/obo/GAZ_00004414' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:GAZ_00004414'>OBO:GAZ_00004414</a> (degree 2), and containing 4 nodes, with a maximal depth of 2, which are <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:6003' target='_blank' title='Go to CHEBI to get more informations about CHEBI:6003'>CHEBI:6003</a>, <a href='http://purl.obolibrary.org/obo/FOODON_03307097' target='_blank' title='Go to FOODON to get more informations about FOODON:03307097'>FOODON:03307097</a> and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:165553' target='_blank' title='Go to CHEBI to get more informations about CHEBI:165553'>CHEBI:165553</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>.</p></li></ul><h4 style="margin: 1em 0 0 0;">Tendrils</h4><p class="paragraph">A tendril is a path starting from a node of degree one, connected to a strongly connected component. We have detected 17.35K tendrils in the graph, involving a total of 18.36K nodes (8.45%) and 18.36K edges (1.32%), with the largest one involving 4 nodes and 4 edges. The detected tendrils, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Tendril starting from the root node <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:25468' target='_blank' title='Go to CHEBI to get more informations about CHEBI:25468'>CHEBI:25468</a> (degree 8), and containing 4 nodes, with a maximal depth of 4, which are <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:164425' target='_blank' title='Go to CHEBI to get more informations about CHEBI:164425'>CHEBI:164425</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:32273' target='_blank' title='Go to CHEBI to get more informations about CHEBI:32273'>CHEBI:32273</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:79852' target='_blank' title='Go to CHEBI to get more informations about CHEBI:79852'>CHEBI:79852</a> and < ...
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:188228' target='_blank' title='Go to CHEBI to get more informations about CHEBI:188228'>CHEBI:188228</a> (degree 5), and containing 4 nodes, with a maximal depth of 4, which are <a href='http://purl.obolibrary.org/obo/FOODON_03308095' target='_blank' title='Go to FOODON to get more informations about FOODON:03308095'>FOODON:03308095</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:112828' target='_blank' title='Go to CHEBI to get more informations about CHEBI:112828'>CHEBI:112828</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:99988' target='_blank' title='Go to CHEBI to get more informations about CHEBI:99988'>CHEBI:99988</a> and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:119012' target='_blank' title='Go to CHEBI to get more informations about CHEBI:119012'>CHEBI:119012</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:17063' target='_blank' title='Go to CHEBI to get more informations about CHEBI:17063'>CHEBI:17063</a> (degree 7), and containing 4 nodes, with a maximal depth of 4, which are <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:88935' target='_blank' title='Go to CHEBI to get more informations about CHEBI:88935'>CHEBI:88935</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:19493' target='_blank' title='Go to CHEBI to get more informations about CHEBI:19493'>CHEBI:19493</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:114912' target='_blank' title='Go to CHEBI to get more informations about CHEBI:114912'>CHEBI:114912</a> and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:177891' target='_blank' title='Go to CHEBI to get more informations about CHEBI:177891'>CHEBI:177891</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:17243' target='_blank' title='Go to CHEBI to get more informations about CHEBI:17243'>CHEBI:17243</a> (degree 12), and containing 3 nodes, with a maximal depth of 3, which are <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:120798' target='_blank' title='Go to CHEBI to get more informations about CHEBI:120798'>CHEBI:120798</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:155408' target='_blank' title='Go to CHEBI to get more informations about CHEBI:155408'>CHEBI:155408</a> and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:66715' target='_blank' title='Go to CHEBI to get more informations about CHEBI:66715'>CHEBI:66715</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:174755' target='_blank' title='Go to CHEBI to get more informations about CHEBI:174755'>CHEBI:174755</a> (degree 3), and containing 3 nodes, with a maximal depth of 3, which are <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:22196' target='_blank' title='Go to CHEBI to get more informations about CHEBI:22196'>CHEBI:22196</a>, <a href='http://purl.obolibrary.org/obo/FOODON_03301626' target='_blank' title='Go to FOODON to get more informations about FOODON:03301626'>FOODON:03301626</a> and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:159273' target='_blank' title='Go to CHEBI to get more informations about CHEBI:159273'>CHEBI:159273</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:73771' target='_blank' title='Go to CHEBI to get more informations about CHEBI:73771'>CHEBI:73771</a> (degree 8), and containing 3 nodes, with a maximal depth of 3, which are <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:187766' target='_blank' title='Go to CHEBI to get more informations about CHEBI:187766'>CHEBI:187766</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:6652' target='_blank' title='Go to CHEBI to get more informations about CHEBI:6652'>CHEBI:6652</a> and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:93422' target='_blank' title='Go to CHEBI to get more informations about CHEBI:93422'>CHEBI:93422</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>.</p></li></ol><p class="paragraph">And other 17.34K tendrils.</p></div>

# %%
# As above, this will save training and validation edge lists.
neg_train_edge_path = merged_edge_filename + ".neg_train"
neg_valid_edge_path = merged_edge_filename + ".neg_valid"

neg_train_edge_graph, neg_valid_edge_graph = negative_graph.random_holdout(train_size=0.8)
neg_train_edge_graph.dump_edges(neg_train_edge_path, edge_type_column='predicate')
neg_valid_edge_graph.dump_edges(neg_valid_edge_path, edge_type_column='predicate')

# %% [markdown]
# ## Generating embeddings and building classifiers with NEAT

# %% [markdown]
# The [NEAT](https://github.com/Knowledge-Graph-Hub/neat-ml) package provides a way to define graph machine learning tasks with a single configuration file. We'll generate such a file here, then run NEAT to produce embeddings and a link prediction classifier.
#
# We'll start by defining some basic parameters, largely based on what we did in the previous section.

# %%
# %pip install neat-ml -U
# %pip install scikit-learn
# Out:
# Requirement already satisfied: neat-ml in /home/harry/kg-env/lib/python3.8/site-packages (0.1.0)
# Requirement already satisfied: click in /home/harry/kg-env/lib/python3.8/site-packages (from neat-ml) (7.1.2)
# Requirement already satisfied: sklearn in /home/harry/kg-env/lib/python3.8/site-packages/sklearn-0.0-py3.8.egg (from neat-ml) (0.0)
# Requirement already satisfied: tqdm in /home/harry/kg-env/lib/python3.8/site-packages (from neat-ml) (4.63.0)
# Requirement already satisfied: pyyaml in /home/harry/kg-env/lib/python3.8/site-packages (from neat-ml) (5.4.1)
# Requirement already satisfied: neat-ml-schema in /home/harry/kg-env/lib/python3.8/site-packages (from neat-ml) (0.1.11)
# Requirement already satisfied: numpy in /home/harry/kg-env/lib/python3.8/site-packages (from neat-ml) (1.22.3)
# Requirement already satisfied: pandas in /home/harry/kg-env/lib/python3.8/site-packages (from neat-ml) (1.4.2)
# Requirement already satisfied: grape in /home/harry/kg-env/lib/python3.8/site-packages (from neat-ml) (0.1.8)
# Requirement already satisfied: botocore in /home/harry/kg-env/lib/python3.8/site-packages (from neat-ml) (1.21.42)
# Requirement already satisfied: boto3 in /home/harry/kg-env/lib/python3.8/site-packages (from neat-ml) (1.18.42)
# Requirement already satisfied: validators in /home/harry/kg-env/lib/python3.8/site-packages (from neat-ml) (0.18.2)
# Requirement already satisfied: linkml in /home/harry/kg-env/lib/python3.8/site-packages (from neat-ml) (1.2.1)
# Requirement already satisfied: linkml-validator in /home/harry/kg-env/lib/python3.8/site-packages (from neat-ml) (0.1.0)
# Requirement already satisfied: transformers in /home/harry/kg-env/lib/python3.8/site-packages/transformers-4.12.5-py3.8.egg (from neat-ml) (4.12.5)
# Requirement already satisfied: opencv-python in /home/harry/kg-env/lib/python3.8/site-packages/opencv_python-4.5.4.60-py3.8-linux-x86_64.egg (from neat-ml) (4.5.4.60)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /home/harry/kg-env/lib/python3.8/site-packages (from boto3->neat-ml) (0.5.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/harry/kg-env/lib/python3.8/site-packages (from boto3->neat-ml) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/harry/kg-env/lib/python3.8/site-packages (from botocore->neat-ml) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/harry/kg-env/lib/python3.8/site-packages (from botocore->neat-ml) (1.26.8)
# Requirement already satisfied: ensmallen>=0.8.5 in /home/harry/kg-env/lib/python3.8/site-packages (from grape->neat-ml) (0.8.5)
# Requirement already satisfied: embiggen>=0.11.12 in /home/harry/kg-env/lib/python3.8/site-packages (from grape->neat-ml) (0.11.12)
# Requirement already satisfied: linkml-dataops in /home/harry/kg-env/lib/python3.8/site-packages (from linkml->neat-ml) (0.1.0)
# Requirement already satisfied: rdflib>=6.0.0 in /home/harry/kg-env/lib/python3.8/site-packages (from linkml->neat-ml) (6.1.1)
# Requirement already satisfied: sphinx in /home/harry/kg-env/lib/python3.8/site-packages (from linkml->neat-ml) (3.5.4)
# Requirement already satisfied: parse in /home/harry/kg-env/lib/python3.8/site-packages (from linkml->neat-ml) (1.19.0)
# Collecting argparse>=1.4.0
#   Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: jsonschema>=3.0.1 in /home/harry/kg-env/lib/python3.8/site-packages (from linkml->neat-ml) (4.4.0)
# Requirement already satisfied: watchdog>=0.9.0 in /home/harry/kg-env/lib/python3.8/site-packages (from linkml->neat-ml) (2.1.6)
# Requirement already satisfied: pyshex>=0.7.20 in /home/harry/kg-env/lib/python3.8/site-packages (from linkml->neat-ml) (0.8.0)
# Requirement already satisfied: pyshexc>=0.8.3 in /home/harry/kg-env/lib/python3.8/site-packages (from linkml->neat-ml) (0.9.0)
# Requirement already satisfied: myst-parser in /home/harry/kg-env/lib/python3.8/site-packages (from linkml->neat-ml) (0.14.0)
# Requirement already satisfied: pydantic in /home/harry/kg-env/lib/python3.8/site-packages (from linkml->neat-ml) (1.9.0)
# Requirement already satisfied: graphviz>=0.10.1 in /home/harry/kg-env/lib/python3.8/site-packages (from linkml->neat-ml) (0.19.1)
# Requirement already satisfied: sqlalchemy>=1.4.31 in /home/harry/kg-env/lib/python3.8/site-packages (from linkml->neat-ml) (1.4.31)
# Requirement already satisfied: requests>=2.22 in /home/harry/kg-env/lib/python3.8/site-packages (from linkml->neat-ml) (2.27.1)
# Requirement already satisfied: isodate>=0.6.0 in /home/harry/kg-env/lib/python3.8/site-packages (from linkml->neat-ml) (0.6.1)
# Requirement already satisfied: jinja2 in /home/harry/kg-env/lib/python3.8/site-packages (from linkml->neat-ml) (3.0.3)
# Requirement already satisfied: openpyxl in /home/harry/kg-env/lib/python3.8/site-packages/openpyxl-3.0.9-py3.8.egg (from linkml->neat-ml) (3.0.9)
# Requirement already satisfied: hbreader in /home/harry/kg-env/lib/python3.8/site-packages (from linkml->neat-ml) (0.9.1)
# Requirement already satisfied: prefixcommons>=0.1.7 in /home/harry/kg-env/lib/python3.8/site-packages (from linkml->neat-ml) (0.1.9)
# Requirement already satisfied: pyjsg>=0.11.6 in /home/harry/kg-env/lib/python3.8/site-packages (from linkml->neat-ml) (0.11.9)
# Requirement already satisfied: jsonasobj2>=1.0.3,~=1.0 in /home/harry/kg-env/lib/python3.8/site-packages (from linkml->neat-ml) (1.0.4)
# Requirement already satisfied: linkml-runtime>=1.2.0 in /home/harry/kg-env/lib/python3.8/site-packages (from linkml->neat-ml) (1.2.2)
# Requirement already satisfied: sphinx-rtd-theme in /home/harry/kg-env/lib/python3.8/site-packages (from linkml->neat-ml) (0.4.3)
# Requirement already satisfied: sphinx-click in /home/harry/kg-env/lib/python3.8/site-packages (from linkml->neat-ml) (2.3.2)
# Requirement already satisfied: stringcase>=1.2.0 in /home/harry/kg-env/lib/python3.8/site-packages (from linkml-validator->neat-ml) (1.2.0)
# Requirement already satisfied: pytest<8.0.0,>=7.1.2 in /home/harry/kg-env/lib/python3.8/site-packages (from neat-ml-schema->neat-ml) (7.1.2)
# Requirement already satisfied: tox<4.0.0,>=3.25.0 in /home/harry/kg-env/lib/python3.8/site-packages (from neat-ml-schema->neat-ml) (3.25.0)
# Requirement already satisfied: pytz>=2020.1 in /home/harry/kg-env/lib/python3.8/site-packages (from pandas->neat-ml) (2021.3)
# Requirement already satisfied: scikit-learn in /home/harry/kg-env/lib/python3.8/site-packages (from sklearn->neat-ml) (1.0.2)
# Requirement already satisfied: filelock in /home/harry/kg-env/lib/python3.8/site-packages (from transformers->neat-ml) (3.6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /home/harry/kg-env/lib/python3.8/site-packages/huggingface_hub-0.2.1-py3.8.egg (from transformers->neat-ml) (0.2.1)
# Requirement already satisfied: packaging>=20.0 in /home/harry/kg-env/lib/python3.8/site-packages (from transformers->neat-ml) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /home/harry/kg-env/lib/python3.8/site-packages (from transformers->neat-ml) (2021.8.28)
# Requirement already satisfied: sacremoses in /home/harry/kg-env/lib/python3.8/site-packages/sacremoses-0.0.46-py3.8.egg (from transformers->neat-ml) (0.0.46)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /home/harry/kg-env/lib/python3.8/site-packages/tokenizers-0.10.3-py3.8-linux-x86_64.egg (from transformers->neat-ml) (0.10.3)
# Requirement already satisfied: decorator>=3.4.0 in /home/harry/kg-env/lib/python3.8/site-packages (from validators->neat-ml) (5.1.1)
# Requirement already satisfied: six>=1.4.0 in /home/harry/kg-env/lib/python3.8/site-packages (from validators->neat-ml) (1.16.0)
# Requirement already satisfied: matplotlib>=3.5.2 in /home/harry/kg-env/lib/python3.8/site-packages (from embiggen>=0.11.12->grape->neat-ml) (3.5.2)
# Requirement already satisfied: sanitize-ml-labels>=1.0.38 in /home/harry/kg-env/lib/python3.8/site-packages (from embiggen>=0.11.12->grape->neat-ml) (1.0.42)
# Requirement already satisfied: extra-keras-metrics>=2.0.7 in /home/harry/kg-env/lib/python3.8/site-packages (from embiggen>=0.11.12->grape->neat-ml) (2.0.7)
# Requirement already satisfied: validate-version-code in /home/harry/kg-env/lib/python3.8/site-packages (from embiggen>=0.11.12->grape->neat-ml) (1.0.4)
# Requirement already satisfied: cache-decorator>=2.1.8 in /home/harry/kg-env/lib/python3.8/site-packages (from embiggen>=0.11.12->grape->neat-ml) (2.1.8)
# Requirement already satisfied: keras-mixed-sequence>=1.0.28 in /home/harry/kg-env/lib/python3.8/site-packages (from embiggen>=0.11.12->grape->neat-ml) (1.0.28)
# Requirement already satisfied: ddd-subplots>=1.0.19 in /home/harry/kg-env/lib/python3.8/site-packages (from embiggen>=0.11.12->grape->neat-ml) (1.0.19)
# Requirement already satisfied: toml~=0.10.0 in /home/harry/kg-env/lib/python3.8/site-packages (from ensmallen>=0.8.5->grape->neat-ml) (0.10.2)
# Requirement already satisfied: compress_json>=1.0.6 in /home/harry/kg-env/lib/python3.8/site-packages (from ensmallen>=0.8.5->grape->neat-ml) (1.0.7)
# Requirement already satisfied: userinput>=1.0.17 in /home/harry/kg-env/lib/python3.8/site-packages (from ensmallen>=0.8.5->grape->neat-ml) (1.0.17)
# Requirement already satisfied: environments_utils>=1.0.4 in /home/harry/kg-env/lib/python3.8/site-packages (from ensmallen>=0.8.5->grape->neat-ml) (1.0.4)
# Requirement already satisfied: py-cpuinfo in /home/harry/kg-env/lib/python3.8/site-packages/py_cpuinfo-8.0.0-py3.8.egg (from ensmallen>=0.8.5->grape->neat-ml) (8.0.0)
# Requirement already satisfied: downloaders>=1.0.15 in /home/harry/kg-env/lib/python3.8/site-packages (from ensmallen>=0.8.5->grape->neat-ml) (1.0.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/harry/kg-env/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers->neat-ml) (4.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/harry/kg-env/lib/python3.8/site-packages (from jsonschema>=3.0.1->linkml->neat-ml) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /home/harry/kg-env/lib/python3.8/site-packages (from jsonschema>=3.0.1->linkml->neat-ml) (5.4.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/harry/kg-env/lib/python3.8/site-packages (from jsonschema>=3.0.1->linkml->neat-ml) (21.4.0)
# Requirement already satisfied: json-flattener>=0.1.9 in /home/harry/kg-env/lib/python3.8/site-packages (from linkml-runtime>=1.2.0->linkml->neat-ml) (0.1.9)
# Requirement already satisfied: deprecated in /home/harry/kg-env/lib/python3.8/site-packages (from linkml-runtime>=1.2.0->linkml->neat-ml) (1.2.13)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/harry/kg-env/lib/python3.8/site-packages (from packaging>=20.0->transformers->neat-ml) (3.0.7)
# Requirement already satisfied: jsonasobj>=1.2.1 in /home/harry/kg-env/lib/python3.8/site-packages (from pyjsg>=0.11.6->linkml->neat-ml) (1.3.1)
# Requirement already satisfied: antlr4-python3-runtime~=4.9 in /home/harry/kg-env/lib/python3.8/site-packages (from pyjsg>=0.11.6->linkml->neat-ml) (4.9.3)
# Requirement already satisfied: sparqlslurper>=0.5.1 in /home/harry/kg-env/lib/python3.8/site-packages (from pyshex>=0.7.20->linkml->neat-ml) (0.5.1)
# Requirement already satisfied: shexjsg>=0.8.1 in /home/harry/kg-env/lib/python3.8/site-packages (from pyshex>=0.7.20->linkml->neat-ml) (0.8.1)
# Requirement already satisfied: sparqlwrapper>=1.8.5 in /home/harry/kg-env/lib/python3.8/site-packages (from pyshex>=0.7.20->linkml->neat-ml) (1.8.5)
# Requirement already satisfied: rdflib-shim in /home/harry/kg-env/lib/python3.8/site-packages (from pyshex>=0.7.20->linkml->neat-ml) (1.0.3)
# Requirement already satisfied: cfgraph>=0.2.1 in /home/harry/kg-env/lib/python3.8/site-packages (from pyshex>=0.7.20->linkml->neat-ml) (0.2.1)
# Requirement already satisfied: chardet in /home/harry/kg-env/lib/python3.8/site-packages (from pyshex>=0.7.20->linkml->neat-ml) (4.0.0)
# Requirement already satisfied: tomli>=1.0.0 in /home/harry/kg-env/lib/python3.8/site-packages (from pytest<8.0.0,>=7.1.2->neat-ml-schema->neat-ml) (1.2.3)
# Requirement already satisfied: py>=1.8.2 in /home/harry/kg-env/lib/python3.8/site-packages (from pytest<8.0.0,>=7.1.2->neat-ml-schema->neat-ml) (1.11.0)
# Requirement already satisfied: iniconfig in /home/harry/kg-env/lib/python3.8/site-packages (from pytest<8.0.0,>=7.1.2->neat-ml-schema->neat-ml) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /home/harry/kg-env/lib/python3.8/site-packages (from pytest<8.0.0,>=7.1.2->neat-ml-schema->neat-ml) (1.0.0)
# Requirement already satisfied: setuptools in /home/harry/kg-env/lib/python3.8/site-packages (from rdflib>=6.0.0->linkml->neat-ml) (60.9.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/harry/kg-env/lib/python3.8/site-packages (from requests>=2.22->linkml->neat-ml) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/harry/kg-env/lib/python3.8/site-packages (from requests>=2.22->linkml->neat-ml) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/harry/kg-env/lib/python3.8/site-packages (from requests>=2.22->linkml->neat-ml) (2.0.12)
# Requirement already satisfied: greenlet!=0.4.17 in /home/harry/kg-env/lib/python3.8/site-packages (from sqlalchemy>=1.4.31->linkml->neat-ml) (1.1.2)
# Requirement already satisfied: virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0 in /home/harry/kg-env/lib/python3.8/site-packages (from tox<4.0.0,>=3.25.0->neat-ml-schema->neat-ml) (20.13.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/harry/kg-env/lib/python3.8/site-packages (from jinja2->linkml->neat-ml) (2.1.0)
# Requirement already satisfied: ruamel.yaml in /home/harry/kg-env/lib/python3.8/site-packages (from linkml-dataops->linkml->neat-ml) (0.17.21)
# Requirement already satisfied: jsonpatch in /home/harry/kg-env/lib/python3.8/site-packages (from linkml-dataops->linkml->neat-ml) (1.32)
# Requirement already satisfied: jsonpath-ng in /home/harry/kg-env/lib/python3.8/site-packages (from linkml-dataops->linkml->neat-ml) (1.5.3)
# Requirement already satisfied: docutils<0.18,>=0.15 in /home/harry/kg-env/lib/python3.8/site-packages (from myst-parser->linkml->neat-ml) (0.16)
# Requirement already satisfied: mdit-py-plugins~=0.2.8 in /home/harry/kg-env/lib/python3.8/site-packages (from myst-parser->linkml->neat-ml) (0.2.8)
# Requirement already satisfied: markdown-it-py<2.0.0,>=1.0.0 in /home/harry/kg-env/lib/python3.8/site-packages (from myst-parser->linkml->neat-ml) (1.1.0)
# Requirement already satisfied: sphinxcontrib-applehelp in /home/harry/kg-env/lib/python3.8/site-packages (from sphinx->linkml->neat-ml) (1.0.2)
# Requirement already satisfied: sphinxcontrib-qthelp in /home/harry/kg-env/lib/python3.8/site-packages (from sphinx->linkml->neat-ml) (1.0.3)
# Requirement already satisfied: Pygments>=2.0 in /home/harry/kg-env/lib/python3.8/site-packages (from sphinx->linkml->neat-ml) (2.11.2)
# Requirement already satisfied: snowballstemmer>=1.1 in /home/harry/kg-env/lib/python3.8/site-packages (from sphinx->linkml->neat-ml) (2.2.0)
# Requirement already satisfied: sphinxcontrib-jsmath in /home/harry/kg-env/lib/python3.8/site-packages (from sphinx->linkml->neat-ml) (1.0.1)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /home/harry/kg-env/lib/python3.8/site-packages (from sphinx->linkml->neat-ml) (0.7.12)
# Requirement already satisfied: imagesize in /home/harry/kg-env/lib/python3.8/site-packages (from sphinx->linkml->neat-ml) (1.3.0)
# Requirement already satisfied: sphinxcontrib-devhelp in /home/harry/kg-env/lib/python3.8/site-packages (from sphinx->linkml->neat-ml) (1.0.2)
# Requirement already satisfied: sphinxcontrib-serializinghtml in /home/harry/kg-env/lib/python3.8/site-packages (from sphinx->linkml->neat-ml) (1.1.5)
# Requirement already satisfied: babel>=1.3 in /home/harry/kg-env/lib/python3.8/site-packages (from sphinx->linkml->neat-ml) (2.9.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp in /home/harry/kg-env/lib/python3.8/site-packages (from sphinx->linkml->neat-ml) (2.0.0)
# Requirement already satisfied: et-xmlfile in /home/harry/kg-env/lib/python3.8/site-packages/et_xmlfile-1.1.0-py3.8.egg (from openpyxl->linkml->neat-ml) (1.1.0)
# Requirement already satisfied: joblib in /home/harry/kg-env/lib/python3.8/site-packages (from sacremoses->transformers->neat-ml) (1.0.1)
# Requirement already satisfied: scipy>=1.1.0 in /home/harry/kg-env/lib/python3.8/site-packages (from scikit-learn->sklearn->neat-ml) (1.8.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/harry/kg-env/lib/python3.8/site-packages/threadpoolctl-3.0.0-py3.8.egg (from scikit-learn->sklearn->neat-ml) (3.0.0)
# Requirement already satisfied: pbr>=2.0 in /home/harry/kg-env/lib/python3.8/site-packages (from sphinx-click->linkml->neat-ml) (5.8.1)
# Requirement already satisfied: humanize>=3.4.1 in /home/harry/kg-env/lib/python3.8/site-packages/humanize-3.12.0-py3.8.egg (from cache-decorator>=2.1.8->embiggen>=0.11.12->grape->neat-ml) (3.12.0)
# Requirement already satisfied: dict-hash>=1.1.25 in /home/harry/kg-env/lib/python3.8/site-packages (from cache-decorator>=2.1.8->embiggen>=0.11.12->grape->neat-ml) (1.1.26)
# Requirement already satisfied: deflate-dict in /home/harry/kg-env/lib/python3.8/site-packages/deflate_dict-1.0.9-py3.8.egg (from cache-decorator>=2.1.8->embiggen>=0.11.12->grape->neat-ml) (1.0.9)
# Requirement already satisfied: compress-pickle>=2.0.1 in /home/harry/kg-env/lib/python3.8/site-packages/compress_pickle-2.1.0-py3.8.egg (from cache-decorator>=2.1.8->embiggen>=0.11.12->grape->neat-ml) (2.1.0)
# Requirement already satisfied: imageio in /home/harry/kg-env/lib/python3.8/site-packages/imageio-2.10.1-py3.8.egg (from ddd-subplots>=1.0.19->embiggen>=0.11.12->grape->neat-ml) (2.10.1)
# Requirement already satisfied: pygifsicle in /home/harry/kg-env/lib/python3.8/site-packages/pygifsicle-1.0.5-py3.8.egg (from ddd-subplots>=1.0.19->embiggen>=0.11.12->grape->neat-ml) (1.0.5)
# Requirement already satisfied: zipp>=3.1.0 in /home/harry/kg-env/lib/python3.8/site-packages (from importlib-resources>=1.4.0->jsonschema>=3.0.1->linkml->neat-ml) (3.7.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/harry/kg-env/lib/python3.8/site-packages/kiwisolver-1.3.2-py3.8-linux-x86_64.egg (from matplotlib>=3.5.2->embiggen>=0.11.12->grape->neat-ml) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/harry/kg-env/lib/python3.8/site-packages/fonttools-4.27.1-py3.8.egg (from matplotlib>=3.5.2->embiggen>=0.11.12->grape->neat-ml) (4.27.1)
# Requirement already satisfied: cycler>=0.10 in /home/harry/kg-env/lib/python3.8/site-packages/cycler-0.10.0-py3.8.egg (from matplotlib>=3.5.2->embiggen>=0.11.12->grape->neat-ml) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/harry/kg-env/lib/python3.8/site-packages/Pillow-8.4.0-py3.8-linux-x86_64.egg (from matplotlib>=3.5.2->embiggen>=0.11.12->grape->neat-ml) (8.4.0)
# Requirement already satisfied: ipython in /home/harry/kg-env/lib/python3.8/site-packages (from userinput>=1.0.17->ensmallen>=0.8.5->grape->neat-ml) (8.1.1)
# Requirement already satisfied: jaro-winkler in /home/harry/kg-env/lib/python3.8/site-packages (from userinput>=1.0.17->ensmallen>=0.8.5->grape->neat-ml) (2.0.0)
# Requirement already satisfied: validate-email in /home/harry/kg-env/lib/python3.8/site-packages/validate_email-1.3-py3.8.egg (from userinput>=1.0.17->ensmallen>=0.8.5->grape->neat-ml) (1.3)
# Requirement already satisfied: IPy in /home/harry/kg-env/lib/python3.8/site-packages/IPy-1.1-py3.8.egg (from userinput>=1.0.17->ensmallen>=0.8.5->grape->neat-ml) (1.1)
# Requirement already satisfied: platformdirs<3,>=2 in /home/harry/kg-env/lib/python3.8/site-packages (from virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0->tox<4.0.0,>=3.25.0->neat-ml-schema->neat-ml) (2.5.1)
# Requirement already satisfied: distlib<1,>=0.3.1 in /home/harry/kg-env/lib/python3.8/site-packages (from virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0->tox<4.0.0,>=3.25.0->neat-ml-schema->neat-ml) (0.3.4)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/harry/kg-env/lib/python3.8/site-packages (from deprecated->linkml-runtime>=1.2.0->linkml->neat-ml) (1.13.3)
# Requirement already satisfied: jsonpointer>=1.9 in /home/harry/kg-env/lib/python3.8/site-packages (from jsonpatch->linkml-dataops->linkml->neat-ml) (2.2)
# Requirement already satisfied: ply in /home/harry/kg-env/lib/python3.8/site-packages (from jsonpath-ng->linkml-dataops->linkml->neat-ml) (3.11)
# Requirement already satisfied: rdflib-jsonld==0.6.1 in /home/harry/kg-env/lib/python3.8/site-packages (from rdflib-shim->pyshex>=0.7.20->linkml->neat-ml) (0.6.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /home/harry/kg-env/lib/python3.8/site-packages (from ruamel.yaml->linkml-dataops->linkml->neat-ml) (0.2.6)
# Requirement already satisfied: pickleshare in /home/harry/kg-env/lib/python3.8/site-packages/pickleshare-0.7.5-py3.8.egg (from ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape->neat-ml) (0.7.5)
# Requirement already satisfied: backcall in /home/harry/kg-env/lib/python3.8/site-packages/backcall-0.2.0-py3.8.egg (from ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape->neat-ml) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/harry/kg-env/lib/python3.8/site-packages (from ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape->neat-ml) (3.0.28)
# Requirement already satisfied: jedi>=0.16 in /home/harry/kg-env/lib/python3.8/site-packages (from ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape->neat-ml) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /home/harry/kg-env/lib/python3.8/site-packages/matplotlib_inline-0.1.3-py3.8.egg (from ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape->neat-ml) (0.1.3)
# Requirement already satisfied: traitlets>=5 in /home/harry/kg-env/lib/python3.8/site-packages/traitlets-5.1.1-py3.8.egg (from ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape->neat-ml) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /home/harry/kg-env/lib/python3.8/site-packages/pexpect-4.8.0-py3.8.egg (from ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape->neat-ml) (4.8.0)
# Requirement already satisfied: stack-data in /home/harry/kg-env/lib/python3.8/site-packages (from ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape->neat-ml) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/harry/kg-env/lib/python3.8/site-packages (from jedi>=0.16->ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape->neat-ml) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/harry/kg-env/lib/python3.8/site-packages/ptyprocess-0.7.0-py3.8.egg (from pexpect>4.3->ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape->neat-ml) (0.7.0)
# Requirement already satisfied: wcwidth in /home/harry/kg-env/lib/python3.8/site-packages/wcwidth-0.2.5-py3.8.egg (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape->neat-ml) (0.2.5)
# Requirement already satisfied: pure-eval in /home/harry/kg-env/lib/python3.8/site-packages (from stack-data->ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape->neat-ml) (0.2.2)
# Requirement already satisfied: asttokens in /home/harry/kg-env/lib/python3.8/site-packages (from stack-data->ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape->neat-ml) (2.0.5)
# Requirement already satisfied: executing in /home/harry/kg-env/lib/python3.8/site-packages (from stack-data->ipython->userinput>=1.0.17->ensmallen>=0.8.5->grape->neat-ml) (0.8.3)
# Installing collected packages: argparse
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kg-obo 0.1 requires kgx==1.5.1, but you have kgx 1.5.7 which is incompatible.
# Successfully installed argparse-1.4.0
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/home/harry/kg-env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in /home/harry/kg-env/lib/python3.8/site-packages (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /home/harry/kg-env/lib/python3.8/site-packages (from scikit-learn) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/harry/kg-env/lib/python3.8/site-packages/threadpoolctl-3.0.0-py3.8.egg (from scikit-learn) (3.0.0)
# Requirement already satisfied: numpy>=1.14.6 in /home/harry/kg-env/lib/python3.8/site-packages (from scikit-learn) (1.22.3)
# Requirement already satisfied: scipy>=1.1.0 in /home/harry/kg-env/lib/python3.8/site-packages (from scikit-learn) (1.8.0)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/home/harry/kg-env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
directed = False # Yes, this is technically a directed network, but we'll treat it as undirected
node_path = merged_node_filename # Positive training nodes
edge_path = train_edge_path # Positive training edges
#valid_edge_path - we've already defined this above
#neg_train_edge_path - we've already defined this above
#neg_valid_edge_path - we've already defined this above

# Embedding parameters
embedding_file_name = "embeddings.tsv"
embedding_history_file_name = "embedding_history.json"
node_embedding_method_name = "SPINE"

# Classifier parameters - NEAT can build multiple classifier types in one run, if specified in the configuration file
edge_method = "Average" # one of EdgeTransformer.methods: Hadamard, Sum, Average, L1, AbsoluteL1, L2, or alternatively a lambda
classifier_type = "Logistic Regression"
classifier_model_outfile = "model_lr.model"
classifier_model_type = "sklearn.linear_model.LogisticRegression"
classifier_model_random_state = 42
classifier_model_max_iter = 1000

# Output parameters
output_directory = "./"
config_filename = "scallops.yaml"

# %%
outstring = f"""
---
Target:
  target_path: {output_directory}

GraphDataConfiguration:
  graph:
    directed: {directed}
    node_path: {node_path}
    edge_path: {edge_path}
    verbose: True
    nodes_column: "id"
    node_list_node_types_column: "category"
    default_node_type: "biolink:NamedThing"
    sources_column: "subject"
    destinations_column: "object"
    default_edge_type: "biolink:related_to"
  evaluation_data:
    valid_data:
      pos_edge_filepath: {valid_edge_path}
      neg_edge_filepath: {neg_valid_edge_path}
    train_data:
      neg_edge_filepath: {neg_train_edge_path}

EmbeddingsConfig:
  filename: {embedding_file_name}
  history_filename: {embedding_history_file_name}
  node_embeddings_params:
    method_name: {node_embedding_method_name}
  tsne_filename: tsne.png

ClassifierContainer:
  classifiers:
    - classifier_id: lr_1
      classifier_name: {classifier_type}
      classifier_type: {classifier_model_type}
      edge_method: {edge_method}
      outfile: {classifier_model_outfile}
      parameters:
        sklearn_params:
          random_state: {classifier_model_random_state}
          max_iter: {classifier_model_max_iter}

ApplyTrainedModelsContainer:
  models:
    - model_id: lr_1
      node_types:
        source:
          - "biolink:NamedThing"
        destination:
          - "biolink:NamedThing"
      cutoff: 0.9
      outfile: lr_protein_predictions.tsv
"""
print(outstring)
with open(config_filename, "w") as outfile:
    outfile.write(outstring)
# Out:
# ---
# Target:
#   target_path: ./
#
# GraphDataConfiguration:
#   graph:
#     directed: False
#     node_path: merged-kg_nodes.tsv
#     edge_path: merged-kg_edges.tsv.train
#     verbose: True
#     nodes_column: "id"
#     node_list_node_types_column: "category"
#     default_node_type: "biolink:NamedThing"
#     sources_column: "subject"
#     destinations_column: "object"
#     default_edge_type: "biolink:related_to"
#   evaluation_data:
#     valid_data:
#       pos_edge_filepath: merged-kg_edges.tsv.valid
#       neg_edge_filepath: merged-kg_edges.tsv.neg_valid
#     train_data:
#       neg_edge_filepath: merged-kg_edges.tsv.neg_train
#
# EmbeddingsConfig:
#   filename: embeddings.tsv
#   history_filename: embedding_history.json
#   node_embeddings_params:
#     method_name: SPINE
#   tsne_filename: tsne.png
#
# ClassifierContainer:
#   classifiers:
#     - classifier_id: lr_1
#       classifier_name: Logistic Regression
#       classifier_type: sklearn.linear_model.LogisticRegression
#       edge_method: Average
#       outfile: model_lr.model
#       parameters:
#         sklearn_params:
#           random_state: 42
#           max_iter: 1000
#
# ApplyTrainedModelsContainer:
#   models:
#     - model_id: lr_1
#       node_types:
#         source:
#           - "biolink:NamedThing"
#         destination:
#           - "biolink:NamedThing"
#       cutoff: 0.9
#       outfile: lr_protein_predictions.tsv

# %%
# !neat run --config $config_filename
# Out:
# --2022-06-28 16:20:36--  https://raw.githubusercontent.com/Knowledge-Graph-Hub/neat-ml/main/tests/resources/test.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4294 (4.2K) [text/plain]
# Saving to: ‘test.yaml.1’
#
# test.yaml.1         100%[===================>]   4.19K  --.-KB/s    in 0.003s
#
# 2022-06-28 16:20:36 (1.23 MB/s) - ‘test.yaml.1’ saved [4294/4294]
#
# /home/harry/kg-env/bin/neat
# Traceback (most recent call last):
#   File "/home/harry/kg-env/bin/neat", line 8, in <module>
#     sys.exit(cli())
#   File "/home/harry/kg-env/lib/python3.8/site-packages/click/core.py", line 829, in __call__
#     return self.main(*args, **kwargs)
#   File "/home/harry/kg-env/lib/python3.8/site-packages/click/core.py", line 782, in main
#     rv = self.invoke(ctx)
#   File "/home/harry/kg-env/lib/python3.8/site-packages/click/core.py", line 1259, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/home/harry/kg-env/lib/python3.8/site-packages/click/core.py", line 1066, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/home/harry/kg-env/lib/python3.8/site-packages/click/core.py", line 610, in invoke
#     return callback(*args, **kwargs)
#   File "/home/harry/kg-env/lib/python3.8/site-packages/neat_ml/cli.py", line 45, in run
#     yhelp = YamlHelper(config)
#   File "/home/harry/kg-env/lib/python3.8/site-packages/neat_ml/yaml_helper/yaml_helper.py", line 147, in __init__
#     if not validate_config(self.yaml):
#   File "/home/harry/kg-env/lib/python3.8/site-packages/neat_ml/yaml_helper/yaml_helper.py", line 43, in validate_config
#     raise RuntimeError
# RuntimeError

# %%
from IPython.display import Image
Image(filename='tsne.png')
